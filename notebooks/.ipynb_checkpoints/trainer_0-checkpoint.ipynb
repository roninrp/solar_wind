# %%
import sys
sys.dont_write_bytecode = True
sys.path.insert(0, "..")
import numpy as np
import pandas as pd
import datetime as dt
from scipy.stats import pearsonr
import pickle
import torch
import torch.nn as nn
import os
import time
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import math
from math import sqrt
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import codes.mnn_Utils as mnn
from codes.make_dataset import DatasetHist
import random

from termcolor import colored

# %%
train_path = "../data/data_generated/train/train_ips_omni_df.csv"
val_path = "../data/data_generated/val/val_ips_omni_df.csv"
test_path = "../data/data_generated/test/test_ips_omni_df.csv"

# %%
full_path = "../data/data_generated/full_df.csv"

# %%
val_dataset = DatasetHist(val_path)
# Out:
# Input features are ['dist', 'hla', 'hlo', 'gla', 'glo', 'carr', 'v', 'er', 'sc_indx', 'time', 'day_total', 'time_trgt', 'input']
# Target features are ['swSpeed_Smth_0']
# begins: 71994 ends: 77399

# %%
len(val_dataset)
# Out:
# 5406

# %%
val_load = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
model = mnn.model_base(xCh=13, LEN=32, emDim=128, dropout=0.2, device=None)

# %%
for i, val in enumerate(val_load):
    print(val[1].shape, val[2].shape, val[1].to(torch.float32).dtype)
    model.eval()
    output = model(val[1].to(torch.float32))
    # print(output)
    loss = F.mse_loss(val[2], output)
    print(loss.item())
    if i > len(val_dataset)/100:
        break
# Out:
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.002494701088223222
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.002659302964279111
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.0053764669459863725
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.018937062894882666
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.031946096143575915
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.037891578355801085
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.03155205378294308
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.0240141916344229
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.014488449709021455
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.005001343805791681
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.0030746416131782013
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.00269821443183148
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.002912580738150708
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.003258542354704912
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.007890556706906535
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.012052000545485482
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.007858039319271735
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.007729632446400384
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.019303938703274397
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.04450270533646841
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.10728279928673319
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.12975241773150828
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.12030052846396617
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.17005076711043682
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.16340745941516108
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.08291884958129604
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.02535200286503785
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.00488424955970776
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.0029817724919537973
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.005029483530546537
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.04541616972579305
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.14858992042546756
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.18922906668058942
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.15158553984377673
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.0968793571892141
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.05522883522419283
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.03201483589568787
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.02296444527084938
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.017399025553499568
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.007268841310654531
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.005810694258331364
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.005976874775579521
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.003579528194444257
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.0024968095050060877
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.002587932376167543
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.003291270175374797
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.003999238597446822
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.007997067980262257
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.03113442202735773
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.0345242809001718
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.018075494969077857
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.0078002149172666565
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.003253102273862706
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.002639786702582861
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.002663046035489119
# torch.Size([16, 13, 32]) torch.Size([16, 1, 16]) torch.float32
# 0.0026249802456489524

# %%
model = mnn.model_base(xCh=13, LEN=32, emDim=128, dropout=0.2, device=None)
model.train()
# Inititialize optimizer ans scheduler
lr = lrs[0]
weight_decay = weight_decays[0]
batch_size = batch_sizes[0]
optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = StepLR(optimizer, step_size=1, gamma=gamma)

data_set = DatasetHist(train_path)
data_load = DataLoader(data_set, batch_size=batch_size, shuffle=True)

for i, batch in enumerate(data_load):
    optimizer.zero_grad()
    x = batch[1].to(torch.float32)
    y = batch[2].to(torch.float32)
    output = model(x)
    is_out_nan = bool(torch.isnan(output).any())
    is_in_nan = bool(torch.isnan(x).any())
    print("model yields NaN:", is_out_nan, ",", "input has NaN:", is_in_nan)
    if is_out_nan:
        print(colored("Input has Nans", "red"))
        break
    loss = F.mse_loss(y, output)
    print(loss.item())
    loss.backward()
    optimizer.step()
    
    if i == 100:
        break
# Out:
# Input features are ['dist', 'hla', 'hlo', 'gla', 'glo', 'carr', 'v', 'er', 'sc_indx', 'time', 'day_total', 'time_trgt', 'input']
# Target features are ['swSpeed_Smth_0']
# begins: 0 ends: 71991
# model yields NaN: False , input has NaN: False
# 0.01662561483681202
# model yields NaN: False , input has NaN: False
# 0.029860835522413254
# model yields NaN: False , input has NaN: False
# 0.017857719212770462
# model yields NaN: False , input has NaN: False
# 0.021620701998472214
# model yields NaN: False , input has NaN: False
# 0.02684231661260128
# model yields NaN: False , input has NaN: False
# 0.021465139463543892
# model yields NaN: False , input has NaN: False
# 0.020347464829683304
# model yields NaN: False , input has NaN: False
# 0.03029012866318226
# model yields NaN: False , input has NaN: False
# 0.020278573036193848
# model yields NaN: False , input has NaN: False
# 0.01630883663892746
# model yields NaN: False , input has NaN: False
# 0.01730329915881157
# model yields NaN: False , input has NaN: False
# 0.01596924103796482
# model yields NaN: False , input has NaN: False
# 0.021466603502631187
# model yields NaN: False , input has NaN: False
# 0.016976509243249893
# model yields NaN: False , input has NaN: False
# 0.017250264063477516
# model yields NaN: False , input has NaN: False
# 0.0190584659576416
# model yields NaN: False , input has NaN: False
# 0.015334086492657661
# model yields NaN: False , input has NaN: False
# 0.016030821949243546
# model yields NaN: False , input has NaN: False
# 0.018389282748103142
# model yields NaN: False , input has NaN: False
# 0.014992514625191689
# model yields NaN: False , input has NaN: False
# 0.03133333474397659
# model yields NaN: False , input has NaN: False
# 0.01745697483420372
# model yields NaN: False , input has NaN: False
# 0.011382835917174816
# model yields NaN: False , input has NaN: False
# 0.018410688266158104
# model yields NaN: False , input has NaN: False
# 0.01699165441095829
# model yields NaN: False , input has NaN: False
# 0.024912413209676743
# model yields NaN: False , input has NaN: False
# 0.01595103181898594
# model yields NaN: False , input has NaN: False
# 0.013363230973482132
# model yields NaN: False , input has NaN: False
# 0.01952805556356907
# model yields NaN: False , input has NaN: False
# 0.018771018832921982
# model yields NaN: False , input has NaN: False
# 0.017631078138947487
# model yields NaN: False , input has NaN: False
# 0.02201594039797783
# model yields NaN: False , input has NaN: False
# 0.01932980678975582
# model yields NaN: False , input has NaN: False
# 0.020031414926052094
# model yields NaN: False , input has NaN: False
# 0.022268392145633698
# model yields NaN: False , input has NaN: False
# 0.01993585377931595
# model yields NaN: False , input has NaN: False
# 0.01708727888762951
# model yields NaN: False , input has NaN: False
# 0.01612432487308979
# model yields NaN: False , input has NaN: False
# 0.022197643294930458
# model yields NaN: False , input has NaN: False
# 0.016060123220086098
# model yields NaN: False , input has NaN: False
# 0.023162785917520523
# model yields NaN: False , input has NaN: False
# 0.018608447164297104
# model yields NaN: False , input has NaN: False
# 0.027042817324399948
# model yields NaN: False , input has NaN: False
# 0.016761666163802147
# model yields NaN: False , input has NaN: False
# 0.016337061300873756
# model yields NaN: False , input has NaN: False
# 0.013778112828731537
# model yields NaN: False , input has NaN: False
# 0.018510080873966217
# model yields NaN: False , input has NaN: False
# 0.017161812633275986
# model yields NaN: False , input has NaN: False
# 0.02148563414812088
# model yields NaN: False , input has NaN: False
# 0.024813411757349968
# model yields NaN: False , input has NaN: False
# 0.021099988371133804
# model yields NaN: False , input has NaN: False
# 0.017354760318994522
# model yields NaN: False , input has NaN: False
# 0.01752774976193905
# model yields NaN: False , input has NaN: False
# 0.018366947770118713
# model yields NaN: False , input has NaN: False
# 0.025148071348667145
# model yields NaN: False , input has NaN: False
# 0.027605440467596054
# model yields NaN: False , input has NaN: False
# 0.020960740745067596
# model yields NaN: False , input has NaN: False
# 0.021819254383444786
# model yields NaN: False , input has NaN: False
# 0.013122698292136192
# model yields NaN: False , input has NaN: False
# 0.02295098826289177
# model yields NaN: False , input has NaN: False
# 0.01631716825067997
# model yields NaN: False , input has NaN: False
# 0.01217951625585556
# model yields NaN: False , input has NaN: False
# 0.029167575761675835
# model yields NaN: False , input has NaN: False
# 0.022382406517863274
# model yields NaN: False , input has NaN: False
# 0.016345124691724777
# model yields NaN: False , input has NaN: False
# 0.01352141797542572
# model yields NaN: False , input has NaN: False
# 0.02874322049319744
# model yields NaN: False , input has NaN: False
# 0.02739502675831318
# model yields NaN: False , input has NaN: False
# 0.02206115610897541
# model yields NaN: False , input has NaN: False
# 0.015908492729067802
# model yields NaN: False , input has NaN: False
# 0.019473083317279816
# model yields NaN: False , input has NaN: False
# 0.016866961494088173
# model yields NaN: False , input has NaN: False
# 0.020900148898363113
# model yields NaN: False , input has NaN: False
# 0.015306927263736725
# model yields NaN: False , input has NaN: False
# 0.020149562507867813
# model yields NaN: False , input has NaN: False
# 0.015555916354060173
# model yields NaN: False , input has NaN: False
# 0.02190466597676277
# model yields NaN: False , input has NaN: False
# 0.018274560570716858
# model yields NaN: False , input has NaN: False
# 0.021729284897446632
# model yields NaN: False , input has NaN: False
# 0.017013024538755417
# model yields NaN: False , input has NaN: False
# 0.020413056015968323
# model yields NaN: False , input has NaN: False
# 0.021746158599853516
# model yields NaN: False , input has NaN: False
# 0.01531529426574707
# model yields NaN: False , input has NaN: False
# 0.030888142064213753
# model yields NaN: False , input has NaN: False
# 0.0187034010887146
# model yields NaN: False , input has NaN: False
# 0.01461863424628973
# model yields NaN: False , input has NaN: False
# 0.02280624955892563
# model yields NaN: False , input has NaN: False
# 0.026105191558599472
# model yields NaN: False , input has NaN: False
# 0.020033063367009163
# model yields NaN: False , input has NaN: False
# 0.017697568982839584
# model yields NaN: False , input has NaN: False
# 0.02375316619873047
# model yields NaN: False , input has NaN: False
# 0.011445535346865654
# model yields NaN: False , input has NaN: False
# 0.016282275319099426
# model yields NaN: False , input has NaN: False
# 0.02029278315603733
# model yields NaN: False , input has NaN: False
# 0.022704005241394043
# model yields NaN: False , input has NaN: False
# 0.019766775891184807
# model yields NaN: False , input has NaN: False
# 0.025133434683084488
# model yields NaN: False , input has NaN: False
# 0.024875853210687637
# model yields NaN: False , input has NaN: False
# 0.013716802932322025
# model yields NaN: False , input has NaN: False
# 0.022582633420825005
# model yields NaN: False , input has NaN: False
# 0.01810714788734913

# %%
runCount = 0
device = torch.device("cuda") 
epochs = 2
train_steps = 2

resultsPath = "../model_ouputs/"
mString = 'base_test_en'
train_path = "../data/data_generated/train/train_ips_omni_df.csv"
val_path = "../data/data_generated/val/val_ips_omni_df.csv"
test_path = "../data/data_generated/test/test_ips_omni_df.csv"

train_set = DatasetHist(train_path)
val_set = DatasetHist(val_path)
test_set = DatasetHist(test_path)


lrs = [1.0e-3,1.0e-2] #learning rate
weight_decays = [1.0e-4,1.0e-3] #weight decay regularization
dropouts = [0.3,0.2,0.4]  #dropouts
batch_sizes = [32,16,64]      # batchsize
gammas = [0.95,0.90,0.85]#,0.80] #learning rate scheduler, reduces the learning rate as training gets cloes to the minima

run_count = 0

startT = time.time()
for lr in lrs:
    for weight_decay in weight_decays:
        for dropout in dropouts:
            for batch_size in batch_sizes:
                for gamma in gammas:
                    start_training(train_set, val_set, test_set, train_steps, epochs)
                    print(lr, weight_decay, dropout, batch_size, gamma)
                    run_count += 1
print(time.time() - startT)
# Out:
# Input features are ['dist', 'hla', 'hlo', 'gla', 'glo', 'carr', 'v', 'er', 'sc_indx', 'time', 'day_total', 'time_trgt', 'input']
# Target features are ['swSpeed_Smth_0']
# begins: 0 ends: 71991
# Input features are ['dist', 'hla', 'hlo', 'gla', 'glo', 'carr', 'v', 'er', 'sc_indx', 'time', 'day_total', 'time_trgt', 'input']
# Target features are ['swSpeed_Smth_0']
# begins: 71994 ends: 77399
# Input features are ['dist', 'hla', 'hlo', 'gla', 'glo', 'carr', 'v', 'er', 'sc_indx', 'time', 'day_total', 'time_trgt', 'input']
# Target features are ['swSpeed_Smth_0']
# begins: 77456 ends: 81211
# bestCorr is defined
# 0 epoch: 1 ; loss 2.0313868522644043
# torch.float32
# 1 epoch: 1 ; loss 2.7876498699188232
# torch.float32
# 2 epoch: 1 ; loss 1.9825559854507446
# torch.float32
# Run 0 [Epoch 1] loss: 4.0754e+01
# val loss tensor(1.1112)
# val loss tensor(2.2841)
# val loss tensor(2.0220)
# val loss tensor(1.2858)
# val loss tensor(2.2990)
# val loss tensor(1.2306)
# val loss tensor(1.7049)
# val loss tensor(1.5523)
# val loss tensor(2.3337)
# val loss tensor(1.4984)
# val loss tensor(1.0602)
# val loss tensor(1.2394)
# val loss tensor(2.2265)
# val loss tensor(2.2479)
# val loss tensor(1.7972)
# val loss tensor(1.9903)
# val loss tensor(2.7642)
# val loss tensor(1.6687)
# val loss tensor(1.5001)
# val loss tensor(1.9430)
# val loss tensor(1.5520)
# val loss tensor(1.2899)
# val loss tensor(0.9382)
# val loss tensor(2.2088)
# val loss tensor(1.4433)
# val loss tensor(1.8839)
# val loss tensor(1.4068)
# val loss tensor(1.4541)
# val loss tensor(1.9887)
# val loss tensor(1.3711)
# val loss tensor(2.0166)
# val loss tensor(2.3453)
# val loss tensor(1.7987)
# val loss tensor(1.9737)
# val loss tensor(0.9634)
# val loss tensor(1.7509)
# val loss tensor(1.5508)
# val loss tensor(1.3871)
# val loss tensor(1.3750)
# val loss tensor(1.1013)
# val loss tensor(1.4416)
# val loss tensor(1.5608)
# val loss tensor(2.9396)
# val loss tensor(1.4679)
# val loss tensor(1.4762)
# val loss tensor(1.6005)
# val loss tensor(1.9343)
# val loss tensor(2.2849)
# val loss tensor(1.8525)
# val loss tensor(1.7247)
# val loss tensor(1.5235)
# val loss tensor(1.5905)
# val loss tensor(1.5772)
# val loss tensor(2.7072)
# val loss tensor(2.6297)
# val loss tensor(0.9720)
# val loss tensor(1.3723)
# val loss tensor(1.8038)
# val loss tensor(3.0353)
# val loss tensor(1.9539)
# val loss tensor(1.6671)
# val loss tensor(1.9599)
# val loss tensor(2.0193)
# val loss tensor(1.5243)
# val loss tensor(1.7466)
# val loss tensor(0.9557)
# val loss tensor(2.0251)
# val loss tensor(1.1234)
# val loss tensor(2.0872)
# val loss tensor(1.5156)
# val loss tensor(1.5109)
# val loss tensor(1.5618)
# val loss tensor(1.2742)
# val loss tensor(1.6926)
# val loss tensor(2.3227)
# val loss tensor(2.5440)
# val loss tensor(1.9796)
# val loss tensor(2.0567)
# val loss tensor(1.0282)
# val loss tensor(1.3186)
# val loss tensor(1.4609)
# val loss tensor(1.8343)
# val loss tensor(1.4556)
# val loss tensor(1.6432)
# val loss tensor(2.1590)
# val loss tensor(3.4151)
# val loss tensor(1.1523)
# val loss tensor(2.2295)
# val loss tensor(1.6955)
# val loss tensor(2.2744)
# val loss tensor(2.2300)
# val loss tensor(2.1044)
# val loss tensor(2.1245)
# val loss tensor(1.9255)
# val loss tensor(0.9680)
# val loss tensor(1.6342)
# val loss tensor(2.1424)
# val loss tensor(2.1116)
# val loss tensor(2.4380)
# val loss tensor(1.3047)
# val loss tensor(1.6214)
# val loss tensor(2.1539)
# val loss tensor(2.3334)
# val loss tensor(1.8162)
# val loss tensor(1.9553)
# val loss tensor(1.6716)
# val loss tensor(1.3576)
# val loss tensor(1.9425)
# val loss tensor(1.9048)
# val loss tensor(1.4662)
# val loss tensor(3.2641)
# val loss tensor(1.2408)
# val loss tensor(1.9087)
# val loss tensor(1.8993)
# val loss tensor(1.2700)
# val loss tensor(1.7012)
# val loss tensor(2.4184)
# val loss tensor(2.0756)
# val loss tensor(1.3907)
# val loss tensor(1.8401)
# val loss tensor(1.1338)
# val loss tensor(1.6967)
# val loss tensor(1.7308)
# val loss tensor(2.3969)
# val loss tensor(2.4370)
# val loss tensor(0.8999)
# val loss tensor(1.8749)
# val loss tensor(1.4142)
# val loss tensor(1.7718)
# val loss tensor(1.5990)
# val loss tensor(1.4956)
# val loss tensor(1.3879)
# val loss tensor(2.0254)
# val loss tensor(1.4556)
# val loss tensor(1.6509)
# val loss tensor(1.7233)
# val loss tensor(2.1286)
# val loss tensor(1.1588)
# val loss tensor(1.8186)
# val loss tensor(1.0491)
# val loss tensor(2.1778)
# val loss tensor(1.7398)
# val loss tensor(1.2683)
# val loss tensor(2.4486)
# val loss tensor(1.9333)
# val loss tensor(1.1335)
# val loss tensor(1.2886)
# val loss tensor(2.1929)
# val loss tensor(1.5288)
# val loss tensor(1.0827)
# val loss tensor(1.6297)
# val loss tensor(1.5112)
# val loss tensor(2.0737)
# val loss tensor(2.0655)
# val loss tensor(1.4832)
# val loss tensor(0.9532)
# val loss tensor(2.4649)
# val loss tensor(1.7651)
# val loss tensor(1.8717)
# val loss tensor(2.1598)
# val loss tensor(1.8798)
# val loss tensor(1.3186)
# val loss tensor(1.2492)
# val loss tensor(2.0346)
# val loss tensor(1.2457)
# val loss tensor(1.6803)
# val loss tensor(1.4682)
# val loss tensor(1.4407)
# val loss tensor(2.0444)
# Run 0 [Epoch 1] val loss: 2.1614e+01
# 0 epoch: 2 ; loss 1.3499886989593506
# torch.float32
# 1 epoch: 2 ; loss 2.0096230506896973
# torch.float32
# 2 epoch: 2 ; loss 2.184203624725342
# torch.float32
# Run 0 [Epoch 2] loss: 3.4712e+01
# val loss tensor(1.5483)
# val loss tensor(1.6202)
# val loss tensor(2.3785)
# val loss tensor(1.6939)
# val loss tensor(1.5640)
# val loss tensor(0.7207)
# val loss tensor(1.9444)
# val loss tensor(1.2764)
# val loss tensor(1.3617)
# val loss tensor(1.3131)
# val loss tensor(1.9054)
# val loss tensor(1.0544)
# val loss tensor(1.6484)
# val loss tensor(1.7622)
# val loss tensor(1.2884)
# val loss tensor(1.6826)
# val loss tensor(0.9674)
# val loss tensor(1.3431)
# val loss tensor(1.0350)
# val loss tensor(1.1810)
# val loss tensor(1.7087)
# val loss tensor(2.0068)
# val loss tensor(2.1132)
# val loss tensor(1.0924)
# val loss tensor(1.9414)
# val loss tensor(2.0572)
# val loss tensor(1.6958)
# val loss tensor(1.6854)
# val loss tensor(2.9094)
# val loss tensor(1.3293)
# val loss tensor(1.3071)
# val loss tensor(1.6284)
# val loss tensor(2.2671)
# val loss tensor(1.2529)
# val loss tensor(1.1846)
# val loss tensor(1.5217)
# val loss tensor(2.0570)
# val loss tensor(1.6150)
# val loss tensor(2.9192)
# val loss tensor(1.6130)
# val loss tensor(1.6882)
# val loss tensor(1.4229)
# val loss tensor(1.5500)
# val loss tensor(1.8968)
# val loss tensor(2.3850)
# val loss tensor(2.1960)
# val loss tensor(1.3091)
# val loss tensor(1.2157)
# val loss tensor(2.0270)
# val loss tensor(2.0287)
# val loss tensor(2.3586)
# val loss tensor(0.9467)
# val loss tensor(1.8652)
# val loss tensor(1.8614)
# val loss tensor(1.4424)
# val loss tensor(1.1327)
# val loss tensor(1.0799)
# val loss tensor(1.1158)
# val loss tensor(1.8638)
# val loss tensor(1.2583)
# val loss tensor(2.0216)
# val loss tensor(2.1615)
# val loss tensor(1.6375)
# val loss tensor(1.3564)
# val loss tensor(2.1544)
# val loss tensor(0.8697)
# val loss tensor(2.0368)
# val loss tensor(1.8182)
# val loss tensor(1.4972)
# val loss tensor(1.4000)
# val loss tensor(1.6545)
# val loss tensor(1.9128)
# val loss tensor(1.1563)
# val loss tensor(2.2938)
# val loss tensor(1.2196)
# val loss tensor(1.2848)
# val loss tensor(1.6637)
# val loss tensor(1.0374)
# val loss tensor(1.4499)
# val loss tensor(1.4485)
# val loss tensor(1.2720)
# val loss tensor(2.4113)
# val loss tensor(1.8745)
# val loss tensor(1.9317)
# val loss tensor(2.0963)
# val loss tensor(0.9366)
# val loss tensor(1.7978)
# val loss tensor(1.8821)
# val loss tensor(1.0648)
# val loss tensor(1.2318)
# val loss tensor(1.6850)
# val loss tensor(2.1892)
# val loss tensor(1.3990)
# val loss tensor(1.8681)
# val loss tensor(1.9487)
# val loss tensor(1.7742)
# val loss tensor(2.2063)
# val loss tensor(1.7346)
# val loss tensor(1.2196)
# val loss tensor(1.7522)
# val loss tensor(1.3948)
# val loss tensor(1.7139)
# val loss tensor(1.9233)
# val loss tensor(0.9015)
# val loss tensor(2.4263)
# val loss tensor(2.3655)
# val loss tensor(1.2845)
# val loss tensor(2.0655)
# val loss tensor(1.5620)
# val loss tensor(2.2782)
# val loss tensor(1.0312)
# val loss tensor(0.9479)
# val loss tensor(0.9545)
# val loss tensor(1.9176)
# val loss tensor(0.8480)
# val loss tensor(1.6732)
# val loss tensor(1.7298)
# val loss tensor(1.6238)
# val loss tensor(1.8770)
# val loss tensor(2.1160)
# val loss tensor(1.5732)
# val loss tensor(1.2011)
# val loss tensor(2.1439)
# val loss tensor(1.7829)
# val loss tensor(1.6597)
# val loss tensor(1.5750)
# val loss tensor(1.5928)
# val loss tensor(1.8204)
# val loss tensor(0.9794)
# val loss tensor(1.6913)
# val loss tensor(1.8476)
# val loss tensor(1.0686)
# val loss tensor(1.9580)
# val loss tensor(1.8968)
# val loss tensor(1.5340)
# val loss tensor(0.9835)
# val loss tensor(1.9038)
# val loss tensor(1.7427)
# val loss tensor(1.5724)
# val loss tensor(1.1196)
# val loss tensor(1.0781)
# val loss tensor(1.5281)
# val loss tensor(2.0331)
# val loss tensor(1.1616)
# val loss tensor(1.6562)
# val loss tensor(1.4714)
# val loss tensor(1.8139)
# val loss tensor(1.0475)
# val loss tensor(1.4558)
# val loss tensor(2.0612)
# val loss tensor(2.1422)
# val loss tensor(1.6060)
# val loss tensor(1.5903)
# val loss tensor(2.3544)
# val loss tensor(1.3627)
# val loss tensor(1.3836)
# val loss tensor(1.5730)
# val loss tensor(1.1485)
# val loss tensor(1.5503)
# val loss tensor(0.9645)
# val loss tensor(1.7479)
# val loss tensor(2.6654)
# val loss tensor(2.3030)
# val loss tensor(1.4278)
# val loss tensor(1.6084)
# val loss tensor(1.5930)
# val loss tensor(1.3421)
# val loss tensor(1.9769)
# val loss tensor(2.3222)
# Run 0 [Epoch 2] val loss: 2.0066e+01
# refY.shape (3756, 1, 16)
# 2 [np.float64(-0.08067489108586254), np.float64(0.08888452590747609), np.float64(0.1492136963741158), np.float64(0.004869138702845121)] 2
# 0.001 0.0001 0.3 32 0.95
# bestCorr is defined
# 0 epoch: 1 ; loss 2.2826414108276367
# torch.float32
# 1 epoch: 1 ; loss 2.557337999343872
# torch.float32
# 2 epoch: 1 ; loss 1.636074185371399
# torch.float32
# Run 1 [Epoch 1] loss: 3.6020e+01
# val loss tensor(0.9449)
# val loss tensor(1.3770)
# val loss tensor(1.5085)
# val loss tensor(1.8155)
# val loss tensor(0.9365)
# val loss tensor(1.0507)
# val loss tensor(0.7337)
# val loss tensor(2.1250)
# val loss tensor(1.0690)
# val loss tensor(1.2298)
# val loss tensor(1.3151)
# val loss tensor(1.0090)
# val loss tensor(1.6325)
# val loss tensor(1.0383)
# val loss tensor(1.5379)
# val loss tensor(0.9157)
# val loss tensor(1.6754)
# val loss tensor(1.6698)
# val loss tensor(1.4421)
# val loss tensor(0.6272)
# val loss tensor(0.6754)
# val loss tensor(1.2238)
# val loss tensor(1.8710)
# val loss tensor(1.5336)
# val loss tensor(1.3154)
# val loss tensor(1.2009)
# val loss tensor(0.6742)
# val loss tensor(1.2453)
# val loss tensor(0.7181)
# val loss tensor(0.9548)
# val loss tensor(1.2973)
# val loss tensor(1.6015)
# val loss tensor(1.3760)
# val loss tensor(1.4190)
# val loss tensor(1.8105)
# val loss tensor(1.2018)
# val loss tensor(2.3426)
# val loss tensor(1.0768)
# val loss tensor(0.9943)
# val loss tensor(1.3312)
# val loss tensor(0.8113)
# val loss tensor(1.2516)
# val loss tensor(1.0382)
# val loss tensor(1.7916)
# val loss tensor(1.7349)
# val loss tensor(1.4526)
# val loss tensor(1.5794)
# val loss tensor(1.4733)
# val loss tensor(1.6002)
# val loss tensor(1.0070)
# val loss tensor(0.7942)
# val loss tensor(1.7429)
# val loss tensor(2.1056)
# val loss tensor(0.8875)
# val loss tensor(0.7141)
# val loss tensor(0.5003)
# val loss tensor(1.6634)
# val loss tensor(0.9473)
# val loss tensor(0.5435)
# val loss tensor(2.6214)
# val loss tensor(1.7844)
# val loss tensor(1.5665)
# val loss tensor(0.7792)
# val loss tensor(1.0899)
# val loss tensor(1.1933)
# val loss tensor(1.1229)
# val loss tensor(1.9428)
# val loss tensor(1.8043)
# val loss tensor(1.4818)
# val loss tensor(1.3306)
# val loss tensor(1.0855)
# val loss tensor(0.8078)
# val loss tensor(0.8814)
# val loss tensor(1.6574)
# val loss tensor(0.8429)
# val loss tensor(1.1254)
# val loss tensor(0.9860)
# val loss tensor(1.1876)
# val loss tensor(1.4956)
# val loss tensor(2.3898)
# val loss tensor(1.0386)
# val loss tensor(1.1334)
# val loss tensor(1.3046)
# val loss tensor(1.6791)
# val loss tensor(1.6561)
# val loss tensor(0.9703)
# val loss tensor(1.8219)
# val loss tensor(1.4693)
# val loss tensor(2.5704)
# val loss tensor(1.7796)
# val loss tensor(1.7272)
# val loss tensor(1.6963)
# val loss tensor(0.8700)
# val loss tensor(1.7228)
# val loss tensor(1.1765)
# val loss tensor(1.0676)
# val loss tensor(0.9381)
# val loss tensor(1.0989)
# val loss tensor(2.0789)
# val loss tensor(1.0256)
# val loss tensor(1.8627)
# val loss tensor(1.2523)
# val loss tensor(1.5386)
# val loss tensor(1.3795)
# val loss tensor(1.3275)
# val loss tensor(1.5275)
# val loss tensor(1.1270)
# val loss tensor(1.1448)
# val loss tensor(1.4996)
# val loss tensor(1.3689)
# val loss tensor(1.4338)
# val loss tensor(1.6979)
# val loss tensor(1.3115)
# val loss tensor(1.3966)
# val loss tensor(0.7138)
# val loss tensor(0.8751)
# val loss tensor(1.4010)
# val loss tensor(1.0258)
# val loss tensor(1.8353)
# val loss tensor(1.6044)
# val loss tensor(0.7067)
# val loss tensor(1.6470)
# val loss tensor(1.1002)
# val loss tensor(1.0062)
# val loss tensor(1.0871)
# val loss tensor(1.1954)
# val loss tensor(0.9232)
# val loss tensor(0.9453)
# val loss tensor(1.2377)
# val loss tensor(0.8275)
# val loss tensor(0.7662)
# val loss tensor(1.1260)
# val loss tensor(1.5871)
# val loss tensor(2.5088)
# val loss tensor(1.7130)
# val loss tensor(1.0085)
# val loss tensor(1.3967)
# val loss tensor(1.0353)
# val loss tensor(1.4481)
# val loss tensor(1.2535)
# val loss tensor(0.9177)
# val loss tensor(0.9349)
# val loss tensor(1.3723)
# val loss tensor(1.7384)
# val loss tensor(2.0744)
# val loss tensor(1.2770)
# val loss tensor(1.6755)
# val loss tensor(1.6080)
# val loss tensor(0.4516)
# val loss tensor(2.1303)
# val loss tensor(1.6227)
# val loss tensor(0.8528)
# val loss tensor(1.3894)
# val loss tensor(0.8719)
# val loss tensor(0.7732)
# val loss tensor(1.0608)
# val loss tensor(1.4738)
# val loss tensor(1.2708)
# val loss tensor(0.7698)
# val loss tensor(1.3416)
# val loss tensor(1.5447)
# val loss tensor(0.7242)
# val loss tensor(1.3347)
# val loss tensor(1.5130)
# val loss tensor(0.8202)
# val loss tensor(1.7120)
# val loss tensor(0.8251)
# val loss tensor(0.8512)
# val loss tensor(0.9248)
# Run 1 [Epoch 1] val loss: 1.5921e+01
# 0 epoch: 2 ; loss 0.9115926623344421
# torch.float32
# 1 epoch: 2 ; loss 1.270296335220337
# torch.float32
# 2 epoch: 2 ; loss 1.3045382499694824
# torch.float32
# Run 1 [Epoch 2] loss: 2.3058e+01
# val loss tensor(1.2574)
# val loss tensor(1.3629)
# val loss tensor(1.4428)
# val loss tensor(2.0403)
# val loss tensor(1.0956)
# val loss tensor(1.0238)
# val loss tensor(1.1709)
# val loss tensor(1.0171)
# val loss tensor(1.0572)
# val loss tensor(1.4200)
# val loss tensor(0.5254)
# val loss tensor(1.1867)
# val loss tensor(1.9109)
# val loss tensor(1.3268)
# val loss tensor(0.7511)
# val loss tensor(1.4115)
# val loss tensor(0.7992)
# val loss tensor(0.7321)
# val loss tensor(1.1442)
# val loss tensor(1.3199)
# val loss tensor(1.2838)
# val loss tensor(0.8560)
# val loss tensor(1.6310)
# val loss tensor(1.1712)
# val loss tensor(1.6637)
# val loss tensor(1.5008)
# val loss tensor(1.3335)
# val loss tensor(1.7231)
# val loss tensor(0.9422)
# val loss tensor(1.5567)
# val loss tensor(1.6148)
# val loss tensor(1.2134)
# val loss tensor(1.9093)
# val loss tensor(1.6945)
# val loss tensor(0.8962)
# val loss tensor(1.1364)
# val loss tensor(0.9380)
# val loss tensor(1.4515)
# val loss tensor(1.7141)
# val loss tensor(1.0129)
# val loss tensor(0.8623)
# val loss tensor(1.2877)
# val loss tensor(1.5956)
# val loss tensor(0.8455)
# val loss tensor(0.8220)
# val loss tensor(1.4422)
# val loss tensor(1.4787)
# val loss tensor(0.8681)
# val loss tensor(0.9321)
# val loss tensor(1.1074)
# val loss tensor(1.4113)
# val loss tensor(1.5757)
# val loss tensor(1.2938)
# val loss tensor(1.1568)
# val loss tensor(0.7918)
# val loss tensor(1.7143)
# val loss tensor(1.5418)
# val loss tensor(1.1596)
# val loss tensor(1.0269)
# val loss tensor(1.7495)
# val loss tensor(1.3327)
# val loss tensor(1.2012)
# val loss tensor(1.1717)
# val loss tensor(1.7877)
# val loss tensor(1.5553)
# val loss tensor(1.3036)
# val loss tensor(0.9038)
# val loss tensor(0.9567)
# val loss tensor(1.4165)
# val loss tensor(0.9934)
# val loss tensor(1.0204)
# val loss tensor(0.9909)
# val loss tensor(1.6955)
# val loss tensor(1.0463)
# val loss tensor(1.3573)
# val loss tensor(1.7285)
# val loss tensor(0.7610)
# val loss tensor(1.7011)
# val loss tensor(1.2566)
# val loss tensor(0.8952)
# val loss tensor(1.5271)
# val loss tensor(0.8672)
# val loss tensor(1.6834)
# val loss tensor(1.8313)
# val loss tensor(1.1615)
# val loss tensor(1.2651)
# val loss tensor(1.6135)
# val loss tensor(1.6012)
# val loss tensor(1.8839)
# val loss tensor(1.6711)
# val loss tensor(1.1040)
# val loss tensor(1.0298)
# val loss tensor(1.5906)
# val loss tensor(1.8949)
# val loss tensor(0.9035)
# val loss tensor(1.5635)
# val loss tensor(1.8623)
# val loss tensor(1.3279)
# val loss tensor(1.4355)
# val loss tensor(1.1337)
# val loss tensor(1.4289)
# val loss tensor(1.9237)
# val loss tensor(1.8478)
# val loss tensor(0.9450)
# val loss tensor(1.0715)
# val loss tensor(1.4695)
# val loss tensor(0.8605)
# val loss tensor(0.8735)
# val loss tensor(1.1087)
# val loss tensor(1.1278)
# val loss tensor(1.7254)
# val loss tensor(0.9481)
# val loss tensor(0.7728)
# val loss tensor(2.1648)
# val loss tensor(1.0833)
# val loss tensor(0.9057)
# val loss tensor(1.6805)
# val loss tensor(1.5220)
# val loss tensor(1.2644)
# val loss tensor(1.4282)
# val loss tensor(1.0788)
# val loss tensor(1.1017)
# val loss tensor(0.9814)
# val loss tensor(1.7227)
# val loss tensor(0.8347)
# val loss tensor(0.6456)
# val loss tensor(0.7087)
# val loss tensor(0.8711)
# val loss tensor(0.9016)
# val loss tensor(0.8312)
# val loss tensor(2.0531)
# val loss tensor(1.1209)
# val loss tensor(1.0555)
# val loss tensor(1.1286)
# val loss tensor(0.8798)
# val loss tensor(0.7022)
# val loss tensor(1.4598)
# val loss tensor(0.6842)
# val loss tensor(0.8215)
# val loss tensor(1.0843)
# val loss tensor(1.0376)
# val loss tensor(0.9486)
# val loss tensor(1.2001)
# val loss tensor(0.8512)
# val loss tensor(1.0020)
# val loss tensor(1.3144)
# val loss tensor(1.5322)
# val loss tensor(0.5976)
# val loss tensor(1.7051)
# val loss tensor(1.0608)
# val loss tensor(2.1580)
# val loss tensor(0.7935)
# val loss tensor(1.2428)
# val loss tensor(2.0273)
# val loss tensor(0.9607)
# val loss tensor(1.1383)
# val loss tensor(1.3930)
# val loss tensor(1.2434)
# val loss tensor(1.6152)
# val loss tensor(1.7695)
# val loss tensor(1.0523)
# val loss tensor(0.7718)
# val loss tensor(1.0984)
# val loss tensor(1.0687)
# val loss tensor(2.0189)
# val loss tensor(0.8256)
# val loss tensor(0.8944)
# val loss tensor(1.4275)
# val loss tensor(1.3653)
# Run 1 [Epoch 2] val loss: 1.5303e+01
# refY.shape (3756, 1, 16)
# 2 [np.float64(0.01892127636229165), np.float64(0.16600983340627193), np.float64(-0.02459282214723551), np.float64(0.0699098456870413)] 2
# 0.001 0.0001 0.3 32 0.9
# bestCorr is defined
# 0 epoch: 1 ; loss 2.4006099700927734
# torch.float32
# 1 epoch: 1 ; loss 1.4913880825042725
# torch.float32
# 2 epoch: 1 ; loss 1.260266661643982
# torch.float32
# Run 2 [Epoch 1] loss: 3.0885e+01
# val loss tensor(0.9206)
# val loss tensor(1.2669)
# val loss tensor(1.5894)
# val loss tensor(0.8490)
# val loss tensor(1.2223)
# val loss tensor(1.5323)
# val loss tensor(1.1451)
# val loss tensor(0.9297)
# val loss tensor(1.1248)
# val loss tensor(1.0127)
# val loss tensor(1.3015)
# val loss tensor(1.0533)
# val loss tensor(1.5007)
# val loss tensor(1.6842)
# val loss tensor(1.5513)
# val loss tensor(1.0777)
# val loss tensor(0.8817)
# val loss tensor(1.5189)
# val loss tensor(0.8804)
# val loss tensor(0.6489)
# val loss tensor(1.3817)
# val loss tensor(1.3058)
# val loss tensor(0.9437)
# val loss tensor(1.1217)
# val loss tensor(1.4437)
# val loss tensor(0.8061)
# val loss tensor(0.5950)
# val loss tensor(0.6481)
# val loss tensor(1.2065)
# val loss tensor(1.7489)
# val loss tensor(0.9849)
# val loss tensor(1.8536)
# val loss tensor(1.3066)
# val loss tensor(0.9717)
# val loss tensor(0.9630)
# val loss tensor(1.2531)
# val loss tensor(1.2327)
# val loss tensor(1.2051)
# val loss tensor(1.4514)
# val loss tensor(1.2491)
# val loss tensor(0.8717)
# val loss tensor(2.1088)
# val loss tensor(1.4819)
# val loss tensor(2.2827)
# val loss tensor(1.2437)
# val loss tensor(1.4912)
# val loss tensor(2.0646)
# val loss tensor(1.5161)
# val loss tensor(2.0137)
# val loss tensor(0.5787)
# val loss tensor(1.0425)
# val loss tensor(1.3215)
# val loss tensor(0.8891)
# val loss tensor(0.6659)
# val loss tensor(0.7107)
# val loss tensor(0.9190)
# val loss tensor(1.5706)
# val loss tensor(1.3145)
# val loss tensor(1.9315)
# val loss tensor(1.1665)
# val loss tensor(0.9798)
# val loss tensor(0.9563)
# val loss tensor(2.0779)
# val loss tensor(0.8573)
# val loss tensor(0.8685)
# val loss tensor(1.7401)
# val loss tensor(1.2430)
# val loss tensor(0.9138)
# val loss tensor(1.6233)
# val loss tensor(1.2111)
# val loss tensor(1.7173)
# val loss tensor(0.6764)
# val loss tensor(1.6275)
# val loss tensor(1.1064)
# val loss tensor(1.0002)
# val loss tensor(1.1811)
# val loss tensor(1.6761)
# val loss tensor(1.7138)
# val loss tensor(1.8187)
# val loss tensor(0.5918)
# val loss tensor(0.7155)
# val loss tensor(1.4526)
# val loss tensor(1.3599)
# val loss tensor(1.1925)
# val loss tensor(1.3821)
# val loss tensor(1.4566)
# val loss tensor(1.2415)
# val loss tensor(2.2752)
# val loss tensor(1.1802)
# val loss tensor(1.7493)
# val loss tensor(1.6075)
# val loss tensor(0.6643)
# val loss tensor(1.7042)
# val loss tensor(0.9221)
# val loss tensor(1.0205)
# val loss tensor(1.2219)
# val loss tensor(1.3959)
# val loss tensor(1.1790)
# val loss tensor(0.6208)
# val loss tensor(0.6326)
# val loss tensor(0.6526)
# val loss tensor(1.8116)
# val loss tensor(0.8847)
# val loss tensor(1.1655)
# val loss tensor(1.2476)
# val loss tensor(1.3708)
# val loss tensor(0.7077)
# val loss tensor(0.8595)
# val loss tensor(0.6467)
# val loss tensor(1.2578)
# val loss tensor(0.8108)
# val loss tensor(1.3559)
# val loss tensor(1.8165)
# val loss tensor(0.7100)
# val loss tensor(0.9604)
# val loss tensor(1.7690)
# val loss tensor(1.5859)
# val loss tensor(0.8199)
# val loss tensor(1.3969)
# val loss tensor(1.9285)
# val loss tensor(1.1605)
# val loss tensor(1.1114)
# val loss tensor(0.9466)
# val loss tensor(1.2209)
# val loss tensor(0.7541)
# val loss tensor(0.5923)
# val loss tensor(1.5474)
# val loss tensor(1.7277)
# val loss tensor(1.9630)
# val loss tensor(0.7741)
# val loss tensor(0.8869)
# val loss tensor(1.0994)
# val loss tensor(1.0472)
# val loss tensor(2.0432)
# val loss tensor(0.9508)
# val loss tensor(0.9920)
# val loss tensor(1.4939)
# val loss tensor(0.9875)
# val loss tensor(1.3378)
# val loss tensor(1.6234)
# val loss tensor(1.2952)
# val loss tensor(1.4766)
# val loss tensor(2.1228)
# val loss tensor(1.0403)
# val loss tensor(1.4054)
# val loss tensor(0.7063)
# val loss tensor(0.9296)
# val loss tensor(0.7128)
# val loss tensor(1.0820)
# val loss tensor(0.9368)
# val loss tensor(0.8875)
# val loss tensor(0.8089)
# val loss tensor(0.7703)
# val loss tensor(0.8583)
# val loss tensor(1.2984)
# val loss tensor(1.0156)
# val loss tensor(1.1813)
# val loss tensor(1.3477)
# val loss tensor(1.2218)
# val loss tensor(1.4839)
# val loss tensor(1.4348)
# val loss tensor(1.2507)
# val loss tensor(0.7931)
# val loss tensor(0.7837)
# val loss tensor(1.4162)
# val loss tensor(0.9302)
# val loss tensor(1.1974)
# val loss tensor(1.7016)
# val loss tensor(0.8744)
# Run 2 [Epoch 1] val loss: 1.5115e+01
# 0 epoch: 2 ; loss 1.6941765546798706
# torch.float32
# 1 epoch: 2 ; loss 1.0969021320343018
# torch.float32
# 2 epoch: 2 ; loss 1.6310346126556396
# torch.float32
# Run 2 [Epoch 2] loss: 2.7053e+01
# val loss tensor(2.4400)
# val loss tensor(1.7319)
# val loss tensor(2.0706)
# val loss tensor(0.9452)
# val loss tensor(1.0944)
# val loss tensor(1.0727)
# val loss tensor(1.0770)
# val loss tensor(1.1451)
# val loss tensor(1.1847)
# val loss tensor(1.4039)
# val loss tensor(1.7804)
# val loss tensor(0.8916)
# val loss tensor(1.3215)
# val loss tensor(1.5496)
# val loss tensor(1.2804)
# val loss tensor(1.1279)
# val loss tensor(0.8852)
# val loss tensor(1.8550)
# val loss tensor(1.0876)
# val loss tensor(1.3193)
# val loss tensor(1.3610)
# val loss tensor(1.1281)
# val loss tensor(0.9195)
# val loss tensor(0.7705)
# val loss tensor(1.3157)
# val loss tensor(1.7208)
# val loss tensor(1.3482)
# val loss tensor(1.6452)
# val loss tensor(0.6718)
# val loss tensor(1.0328)
# val loss tensor(1.3818)
# val loss tensor(0.7714)
# val loss tensor(1.5373)
# val loss tensor(0.9207)
# val loss tensor(0.7839)
# val loss tensor(0.8268)
# val loss tensor(0.9349)
# val loss tensor(0.6241)
# val loss tensor(1.3820)
# val loss tensor(1.1188)
# val loss tensor(1.2042)
# val loss tensor(1.7927)
# val loss tensor(2.1348)
# val loss tensor(1.4966)
# val loss tensor(1.2200)
# val loss tensor(1.4991)
# val loss tensor(1.4136)
# val loss tensor(1.1614)
# val loss tensor(0.9416)
# val loss tensor(1.1991)
# val loss tensor(1.2976)
# val loss tensor(0.9143)
# val loss tensor(1.0073)
# val loss tensor(0.6490)
# val loss tensor(0.9441)
# val loss tensor(1.3370)
# val loss tensor(0.8630)
# val loss tensor(1.2055)
# val loss tensor(1.3770)
# val loss tensor(0.8521)
# val loss tensor(1.0777)
# val loss tensor(1.2239)
# val loss tensor(1.0129)
# val loss tensor(1.1000)
# val loss tensor(0.7640)
# val loss tensor(0.9729)
# val loss tensor(1.0040)
# val loss tensor(1.7886)
# val loss tensor(1.3430)
# val loss tensor(0.7223)
# val loss tensor(1.0507)
# val loss tensor(0.7338)
# val loss tensor(2.1561)
# val loss tensor(1.8675)
# val loss tensor(0.4092)
# val loss tensor(1.1958)
# val loss tensor(0.8249)
# val loss tensor(0.7816)
# val loss tensor(1.2557)
# val loss tensor(1.0267)
# val loss tensor(0.7860)
# val loss tensor(1.4308)
# val loss tensor(1.0226)
# val loss tensor(1.1282)
# val loss tensor(1.1586)
# val loss tensor(1.3523)
# val loss tensor(0.6964)
# val loss tensor(1.5536)
# val loss tensor(0.7600)
# val loss tensor(0.7512)
# val loss tensor(0.8743)
# val loss tensor(1.8874)
# val loss tensor(0.6961)
# val loss tensor(1.3586)
# val loss tensor(0.6194)
# val loss tensor(1.4759)
# val loss tensor(0.7309)
# val loss tensor(1.1815)
# val loss tensor(1.0075)
# val loss tensor(0.9495)
# val loss tensor(0.6087)
# val loss tensor(1.1893)
# val loss tensor(1.6195)
# val loss tensor(0.9627)
# val loss tensor(1.2049)
# val loss tensor(0.6908)
# val loss tensor(0.5787)
# val loss tensor(1.0487)
# val loss tensor(0.7836)
# val loss tensor(1.1335)
# val loss tensor(1.7813)
# val loss tensor(1.3570)
# val loss tensor(0.5799)
# val loss tensor(1.4130)
# val loss tensor(0.7791)
# val loss tensor(1.5211)
# val loss tensor(0.6402)
# val loss tensor(1.7646)
# val loss tensor(1.6004)
# val loss tensor(1.7317)
# val loss tensor(1.2801)
# val loss tensor(1.3264)
# val loss tensor(1.1547)
# val loss tensor(1.8816)
# val loss tensor(0.9328)
# val loss tensor(1.0782)
# val loss tensor(1.0993)
# val loss tensor(0.9058)
# val loss tensor(0.8410)
# val loss tensor(1.0140)
# val loss tensor(0.9675)
# val loss tensor(0.7687)
# val loss tensor(1.3730)
# val loss tensor(1.1400)
# val loss tensor(1.0636)
# val loss tensor(1.1411)
# val loss tensor(1.0111)
# val loss tensor(0.7365)
# val loss tensor(1.8187)
# val loss tensor(1.2117)
# val loss tensor(0.9016)
# val loss tensor(1.3098)
# val loss tensor(2.4915)
# val loss tensor(1.9677)
# val loss tensor(1.3003)
# val loss tensor(0.7528)
# val loss tensor(1.2097)
# val loss tensor(0.9244)
# val loss tensor(1.0719)
# val loss tensor(0.8166)
# val loss tensor(1.0934)
# val loss tensor(1.2006)
# val loss tensor(1.3031)
# val loss tensor(1.0521)
# val loss tensor(1.3994)
# val loss tensor(1.5260)
# val loss tensor(0.9620)
# val loss tensor(0.9774)
# val loss tensor(1.2002)
# val loss tensor(0.8896)
# val loss tensor(1.8214)
# val loss tensor(0.9436)
# val loss tensor(2.1491)
# val loss tensor(0.9283)
# val loss tensor(0.6715)
# val loss tensor(1.2311)
# val loss tensor(0.8033)
# val loss tensor(0.7038)
# val loss tensor(1.4505)
# Run 2 [Epoch 2] val loss: 1.4557e+01
# refY.shape (3756, 1, 16)
# 2 [np.float64(-0.03761392836901149), np.float64(0.05046521641503778), np.float64(0.16877668193495848), np.float64(-0.0795922427358496)] 2
# 0.001 0.0001 0.3 32 0.85
# bestCorr is defined
# 0 epoch: 1 ; loss 2.1104531288146973
# torch.float32
# 1 epoch: 1 ; loss 0.5558554530143738
# torch.float32
# 2 epoch: 1 ; loss 0.6727944016456604
# torch.float32
# Run 3 [Epoch 1] loss: 2.0722e+01
# val loss tensor(0.7900)
# val loss tensor(1.8038)
# val loss tensor(2.0049)
# val loss tensor(0.3992)
# val loss tensor(0.7895)
# val loss tensor(0.3987)
# val loss tensor(1.3591)
# val loss tensor(0.4954)
# val loss tensor(1.2890)
# val loss tensor(1.4047)
# val loss tensor(1.2138)
# val loss tensor(0.8910)
# val loss tensor(1.6681)
# val loss tensor(0.6428)
# val loss tensor(1.6018)
# val loss tensor(1.8694)
# val loss tensor(0.9497)
# val loss tensor(0.5038)
# val loss tensor(1.1656)
# val loss tensor(1.9594)
# val loss tensor(1.7600)
# val loss tensor(1.7321)
# val loss tensor(1.0314)
# val loss tensor(0.7682)
# val loss tensor(0.5377)
# val loss tensor(1.5986)
# val loss tensor(1.0738)
# val loss tensor(0.9858)
# val loss tensor(0.4729)
# val loss tensor(1.0721)
# val loss tensor(1.0608)
# val loss tensor(0.9160)
# val loss tensor(0.5040)
# val loss tensor(2.0632)
# val loss tensor(2.3294)
# val loss tensor(1.6768)
# val loss tensor(0.9561)
# val loss tensor(1.5772)
# val loss tensor(1.1350)
# val loss tensor(0.9940)
# val loss tensor(1.2130)
# val loss tensor(1.0188)
# val loss tensor(2.3610)
# val loss tensor(0.6558)
# val loss tensor(0.8515)
# val loss tensor(2.5106)
# val loss tensor(0.9450)
# val loss tensor(1.2607)
# val loss tensor(0.8843)
# val loss tensor(1.9076)
# val loss tensor(1.2491)
# val loss tensor(1.1722)
# val loss tensor(1.2455)
# val loss tensor(1.5305)
# val loss tensor(1.4383)
# val loss tensor(1.9270)
# val loss tensor(2.3043)
# val loss tensor(1.3650)
# val loss tensor(1.3748)
# val loss tensor(1.1855)
# val loss tensor(0.5450)
# val loss tensor(0.8507)
# val loss tensor(1.5824)
# val loss tensor(0.4099)
# val loss tensor(0.5984)
# val loss tensor(1.2965)
# val loss tensor(2.3315)
# val loss tensor(0.9846)
# val loss tensor(0.3482)
# val loss tensor(1.3784)
# val loss tensor(1.8390)
# val loss tensor(0.8230)
# val loss tensor(1.6084)
# val loss tensor(0.8795)
# val loss tensor(0.8191)
# val loss tensor(1.3233)
# val loss tensor(1.2668)
# val loss tensor(1.3571)
# val loss tensor(0.5698)
# val loss tensor(0.9915)
# val loss tensor(3.2113)
# val loss tensor(1.2198)
# val loss tensor(0.8464)
# val loss tensor(0.8011)
# val loss tensor(0.6506)
# val loss tensor(1.4256)
# val loss tensor(1.3487)
# val loss tensor(1.4785)
# val loss tensor(1.3065)
# val loss tensor(0.5972)
# val loss tensor(1.3220)
# val loss tensor(1.1007)
# val loss tensor(1.2989)
# val loss tensor(0.7497)
# val loss tensor(1.1159)
# val loss tensor(1.3834)
# val loss tensor(1.3592)
# val loss tensor(1.4772)
# val loss tensor(0.5659)
# val loss tensor(0.6454)
# val loss tensor(3.0912)
# val loss tensor(1.3596)
# val loss tensor(0.5931)
# val loss tensor(0.4471)
# val loss tensor(0.5246)
# val loss tensor(0.4395)
# val loss tensor(1.5175)
# val loss tensor(1.0706)
# val loss tensor(0.3951)
# val loss tensor(0.8554)
# val loss tensor(0.9705)
# val loss tensor(1.0453)
# val loss tensor(0.5553)
# val loss tensor(1.4194)
# val loss tensor(1.1532)
# val loss tensor(1.2803)
# val loss tensor(0.6339)
# val loss tensor(1.0885)
# val loss tensor(0.7794)
# val loss tensor(2.8387)
# val loss tensor(0.5987)
# val loss tensor(1.3489)
# val loss tensor(1.2838)
# val loss tensor(0.4161)
# val loss tensor(1.0569)
# val loss tensor(1.0773)
# val loss tensor(0.5327)
# val loss tensor(1.0002)
# val loss tensor(1.4817)
# val loss tensor(1.2374)
# val loss tensor(1.4954)
# val loss tensor(0.8844)
# val loss tensor(1.5197)
# val loss tensor(0.7696)
# val loss tensor(1.1103)
# val loss tensor(0.3555)
# val loss tensor(1.1618)
# val loss tensor(1.5571)
# val loss tensor(1.1653)
# val loss tensor(1.3905)
# val loss tensor(1.3387)
# val loss tensor(0.5160)
# val loss tensor(1.4568)
# val loss tensor(1.4495)
# val loss tensor(1.7532)
# val loss tensor(1.1316)
# val loss tensor(1.8391)
# val loss tensor(0.4383)
# val loss tensor(0.7080)
# val loss tensor(0.9928)
# val loss tensor(0.9117)
# val loss tensor(0.8824)
# val loss tensor(0.7456)
# val loss tensor(0.7253)
# val loss tensor(2.0263)
# val loss tensor(0.6140)
# val loss tensor(1.5207)
# val loss tensor(1.7476)
# val loss tensor(0.6700)
# val loss tensor(1.2534)
# val loss tensor(1.0267)
# val loss tensor(0.4172)
# val loss tensor(0.8992)
# val loss tensor(0.5978)
# val loss tensor(1.3670)
# val loss tensor(0.6591)
# val loss tensor(1.2736)
# val loss tensor(0.6043)
# val loss tensor(1.5689)
# val loss tensor(1.3926)
# val loss tensor(1.3526)
# val loss tensor(1.4082)
# val loss tensor(1.3324)
# val loss tensor(1.8724)
# val loss tensor(0.7670)
# val loss tensor(1.3045)
# val loss tensor(0.6350)
# val loss tensor(1.2571)
# val loss tensor(0.8031)
# val loss tensor(0.6823)
# val loss tensor(1.1404)
# val loss tensor(1.3013)
# val loss tensor(1.3009)
# val loss tensor(1.9784)
# val loss tensor(1.0913)
# val loss tensor(0.5316)
# val loss tensor(1.0350)
# val loss tensor(2.0359)
# val loss tensor(1.5479)
# val loss tensor(0.4047)
# val loss tensor(1.5433)
# val loss tensor(1.6977)
# val loss tensor(2.0867)
# val loss tensor(1.8093)
# val loss tensor(0.6991)
# val loss tensor(1.3362)
# val loss tensor(1.7325)
# val loss tensor(0.6354)
# val loss tensor(0.5191)
# val loss tensor(0.6007)
# val loss tensor(0.9821)
# val loss tensor(0.6287)
# val loss tensor(0.8422)
# val loss tensor(0.4350)
# val loss tensor(0.6369)
# val loss tensor(0.4328)
# val loss tensor(0.8249)
# val loss tensor(0.9383)
# val loss tensor(0.8400)
# val loss tensor(1.2915)
# val loss tensor(1.3222)
# val loss tensor(0.6385)
# val loss tensor(1.2542)
# val loss tensor(0.7915)
# val loss tensor(1.2231)
# val loss tensor(0.6647)
# val loss tensor(0.6740)
# val loss tensor(0.9200)
# val loss tensor(0.8612)
# val loss tensor(0.6090)
# val loss tensor(1.8298)
# val loss tensor(0.6204)
# val loss tensor(0.6603)
# val loss tensor(0.3975)
# val loss tensor(0.9741)
# val loss tensor(0.4549)
# val loss tensor(0.6448)
# val loss tensor(0.4862)
# val loss tensor(0.4250)
# val loss tensor(2.3844)
# val loss tensor(0.8328)
# val loss tensor(0.9394)
# val loss tensor(1.0991)
# val loss tensor(1.8641)
# val loss tensor(0.5714)
# val loss tensor(0.7667)
# val loss tensor(1.2961)
# val loss tensor(1.2909)
# val loss tensor(1.1058)
# val loss tensor(1.3705)
# val loss tensor(0.7380)
# val loss tensor(1.1520)
# val loss tensor(0.7778)
# val loss tensor(1.0734)
# val loss tensor(1.2934)
# val loss tensor(0.4531)
# val loss tensor(0.8977)
# val loss tensor(2.8335)
# val loss tensor(1.0488)
# val loss tensor(2.1847)
# val loss tensor(1.9615)
# val loss tensor(0.9779)
# val loss tensor(1.2468)
# val loss tensor(0.9533)
# val loss tensor(0.8828)
# val loss tensor(1.4508)
# val loss tensor(0.4660)
# val loss tensor(2.5164)
# val loss tensor(1.2400)
# val loss tensor(0.6097)
# val loss tensor(1.0403)
# val loss tensor(1.1150)
# val loss tensor(1.0499)
# val loss tensor(1.9271)
# val loss tensor(1.8313)
# val loss tensor(1.2236)
# val loss tensor(1.7898)
# val loss tensor(0.5880)
# val loss tensor(2.0035)
# val loss tensor(0.9573)
# val loss tensor(0.7510)
# val loss tensor(0.6653)
# val loss tensor(0.8032)
# val loss tensor(0.6584)
# val loss tensor(0.7034)
# val loss tensor(0.7542)
# val loss tensor(1.1520)
# val loss tensor(1.4460)
# val loss tensor(1.8618)
# val loss tensor(1.7383)
# val loss tensor(1.0193)
# val loss tensor(0.5394)
# val loss tensor(1.0962)
# val loss tensor(1.5112)
# val loss tensor(0.3385)
# val loss tensor(1.3920)
# val loss tensor(0.7133)
# val loss tensor(1.2186)
# val loss tensor(1.1175)
# val loss tensor(0.4597)
# val loss tensor(0.6813)
# val loss tensor(0.6511)
# val loss tensor(1.8104)
# val loss tensor(1.5624)
# val loss tensor(0.6102)
# val loss tensor(1.1213)
# val loss tensor(1.3038)
# val loss tensor(0.8722)
# val loss tensor(0.5435)
# val loss tensor(0.9212)
# val loss tensor(1.5092)
# val loss tensor(1.1171)
# val loss tensor(0.8169)
# val loss tensor(1.5527)
# val loss tensor(1.2792)
# val loss tensor(0.9767)
# val loss tensor(1.1806)
# val loss tensor(1.7441)
# val loss tensor(0.9293)
# val loss tensor(0.4159)
# val loss tensor(1.9914)
# val loss tensor(0.4229)
# val loss tensor(0.6342)
# val loss tensor(0.9718)
# val loss tensor(0.4717)
# val loss tensor(0.7631)
# val loss tensor(1.3518)
# val loss tensor(1.2850)
# val loss tensor(1.0531)
# val loss tensor(1.4270)
# val loss tensor(0.8194)
# val loss tensor(0.6802)
# val loss tensor(0.9127)
# val loss tensor(1.2933)
# val loss tensor(1.0803)
# val loss tensor(1.8253)
# val loss tensor(0.5824)
# val loss tensor(0.7755)
# val loss tensor(1.2139)
# val loss tensor(1.0025)
# val loss tensor(0.7285)
# val loss tensor(1.0611)
# val loss tensor(0.5939)
# val loss tensor(1.2573)
# val loss tensor(1.4879)
# val loss tensor(1.6710)
# val loss tensor(0.7833)
# val loss tensor(0.9423)
# Run 3 [Epoch 1] val loss: 1.3797e+01
# 0 epoch: 2 ; loss 2.645869255065918
# torch.float32
# 1 epoch: 2 ; loss 1.0567646026611328
# torch.float32
# 2 epoch: 2 ; loss 1.3515921831130981
# torch.float32
# Run 3 [Epoch 2] loss: 2.9355e+01
# val loss tensor(0.8652)
# val loss tensor(0.9123)
# val loss tensor(0.5662)
# val loss tensor(0.4983)
# val loss tensor(0.9049)
# val loss tensor(2.0326)
# val loss tensor(0.6639)
# val loss tensor(1.5601)
# val loss tensor(0.2999)
# val loss tensor(1.5822)
# val loss tensor(0.6288)
# val loss tensor(1.7619)
# val loss tensor(0.7801)
# val loss tensor(1.1032)
# val loss tensor(0.4809)
# val loss tensor(1.3129)
# val loss tensor(1.2978)
# val loss tensor(0.5656)
# val loss tensor(1.2659)
# val loss tensor(0.8382)
# val loss tensor(1.1207)
# val loss tensor(0.8378)
# val loss tensor(0.5489)
# val loss tensor(0.6421)
# val loss tensor(1.4978)
# val loss tensor(0.6174)
# val loss tensor(0.4580)
# val loss tensor(1.7325)
# val loss tensor(0.9770)
# val loss tensor(0.4523)
# val loss tensor(0.3771)
# val loss tensor(0.7343)
# val loss tensor(1.0668)
# val loss tensor(0.4969)
# val loss tensor(1.9066)
# val loss tensor(2.1674)
# val loss tensor(0.5677)
# val loss tensor(0.5217)
# val loss tensor(0.9727)
# val loss tensor(0.6939)
# val loss tensor(0.5496)
# val loss tensor(1.4120)
# val loss tensor(1.0201)
# val loss tensor(1.1212)
# val loss tensor(0.4577)
# val loss tensor(0.9985)
# val loss tensor(1.9669)
# val loss tensor(1.1268)
# val loss tensor(0.5016)
# val loss tensor(0.7555)
# val loss tensor(2.3863)
# val loss tensor(1.3362)
# val loss tensor(1.9503)
# val loss tensor(0.5605)
# val loss tensor(1.0320)
# val loss tensor(2.1000)
# val loss tensor(1.2732)
# val loss tensor(0.6789)
# val loss tensor(1.3155)
# val loss tensor(1.4066)
# val loss tensor(0.4484)
# val loss tensor(1.1664)
# val loss tensor(0.9595)
# val loss tensor(1.0280)
# val loss tensor(0.9267)
# val loss tensor(0.6447)
# val loss tensor(1.9464)
# val loss tensor(1.3179)
# val loss tensor(1.5253)
# val loss tensor(0.4033)
# val loss tensor(0.9666)
# val loss tensor(0.9082)
# val loss tensor(1.1998)
# val loss tensor(0.3606)
# val loss tensor(0.4723)
# val loss tensor(1.2408)
# val loss tensor(1.1482)
# val loss tensor(0.8859)
# val loss tensor(0.7617)
# val loss tensor(0.7462)
# val loss tensor(0.4765)
# val loss tensor(0.7962)
# val loss tensor(1.1289)
# val loss tensor(2.3867)
# val loss tensor(0.6653)
# val loss tensor(1.2410)
# val loss tensor(1.4924)
# val loss tensor(1.2960)
# val loss tensor(0.9976)
# val loss tensor(0.6843)
# val loss tensor(1.8221)
# val loss tensor(1.5247)
# val loss tensor(0.5229)
# val loss tensor(0.7460)
# val loss tensor(1.1154)
# val loss tensor(0.9337)
# val loss tensor(0.8799)
# val loss tensor(1.4406)
# val loss tensor(0.9061)
# val loss tensor(0.9243)
# val loss tensor(1.0030)
# val loss tensor(1.4593)
# val loss tensor(1.1313)
# val loss tensor(0.7231)
# val loss tensor(1.2423)
# val loss tensor(1.0459)
# val loss tensor(0.8591)
# val loss tensor(0.6781)
# val loss tensor(0.7921)
# val loss tensor(0.4479)
# val loss tensor(1.0288)
# val loss tensor(0.8448)
# val loss tensor(1.4386)
# val loss tensor(1.1606)
# val loss tensor(0.9086)
# val loss tensor(0.5301)
# val loss tensor(0.5188)
# val loss tensor(1.3366)
# val loss tensor(1.5660)
# val loss tensor(1.9432)
# val loss tensor(0.3916)
# val loss tensor(0.5361)
# val loss tensor(1.5706)
# val loss tensor(0.9590)
# val loss tensor(0.5523)
# val loss tensor(0.6390)
# val loss tensor(0.6330)
# val loss tensor(1.6391)
# val loss tensor(0.9750)
# val loss tensor(1.4540)
# val loss tensor(0.3989)
# val loss tensor(1.1317)
# val loss tensor(2.1354)
# val loss tensor(0.5823)
# val loss tensor(1.6134)
# val loss tensor(0.8905)
# val loss tensor(0.7716)
# val loss tensor(1.4733)
# val loss tensor(0.6419)
# val loss tensor(0.6087)
# val loss tensor(1.1662)
# val loss tensor(1.5270)
# val loss tensor(1.8335)
# val loss tensor(0.6046)
# val loss tensor(1.6806)
# val loss tensor(0.4824)
# val loss tensor(1.3451)
# val loss tensor(1.7822)
# val loss tensor(1.9693)
# val loss tensor(0.6673)
# val loss tensor(0.6456)
# val loss tensor(0.7084)
# val loss tensor(1.7788)
# val loss tensor(0.9793)
# val loss tensor(1.4516)
# val loss tensor(1.4239)
# val loss tensor(0.9995)
# val loss tensor(1.0087)
# val loss tensor(0.9556)
# val loss tensor(2.2869)
# val loss tensor(1.8590)
# val loss tensor(1.9641)
# val loss tensor(2.2005)
# val loss tensor(1.4505)
# val loss tensor(0.7318)
# val loss tensor(1.3192)
# val loss tensor(0.5614)
# val loss tensor(1.9007)
# val loss tensor(1.0514)
# val loss tensor(0.3836)
# val loss tensor(0.8716)
# val loss tensor(1.6959)
# val loss tensor(0.5934)
# val loss tensor(1.7575)
# val loss tensor(1.0064)
# val loss tensor(0.6444)
# val loss tensor(0.3269)
# val loss tensor(3.4457)
# val loss tensor(1.1066)
# val loss tensor(0.4057)
# val loss tensor(2.2578)
# val loss tensor(2.0308)
# val loss tensor(2.0371)
# val loss tensor(1.1832)
# val loss tensor(0.5562)
# val loss tensor(0.6519)
# val loss tensor(1.9879)
# val loss tensor(0.4819)
# val loss tensor(1.7811)
# val loss tensor(0.6219)
# val loss tensor(0.4288)
# val loss tensor(0.5891)
# val loss tensor(1.6105)
# val loss tensor(1.1948)
# val loss tensor(1.5847)
# val loss tensor(0.7480)
# val loss tensor(0.9465)
# val loss tensor(1.6348)
# val loss tensor(0.8190)
# val loss tensor(0.9656)
# val loss tensor(2.2175)
# val loss tensor(0.4135)
# val loss tensor(0.9388)
# val loss tensor(2.3205)
# val loss tensor(0.6433)
# val loss tensor(0.7641)
# val loss tensor(1.9953)
# val loss tensor(0.6617)
# val loss tensor(0.3469)
# val loss tensor(0.8743)
# val loss tensor(1.7846)
# val loss tensor(1.0169)
# val loss tensor(1.3203)
# val loss tensor(0.9572)
# val loss tensor(1.4529)
# val loss tensor(1.2045)
# val loss tensor(0.7256)
# val loss tensor(1.4827)
# val loss tensor(0.8845)
# val loss tensor(1.1378)
# val loss tensor(0.8405)
# val loss tensor(0.7718)
# val loss tensor(1.0584)
# val loss tensor(0.9038)
# val loss tensor(0.8781)
# val loss tensor(0.9406)
# val loss tensor(1.1848)
# val loss tensor(0.6877)
# val loss tensor(2.3461)
# val loss tensor(0.6723)
# val loss tensor(0.8934)
# val loss tensor(1.1880)
# val loss tensor(0.9676)
# val loss tensor(1.5862)
# val loss tensor(0.9111)
# val loss tensor(1.2794)
# val loss tensor(0.5354)
# val loss tensor(0.7667)
# val loss tensor(0.6947)
# val loss tensor(1.2357)
# val loss tensor(1.3717)
# val loss tensor(0.8248)
# val loss tensor(0.7557)
# val loss tensor(0.5552)
# val loss tensor(0.5237)
# val loss tensor(1.1249)
# val loss tensor(1.9811)
# val loss tensor(0.7825)
# val loss tensor(0.6620)
# val loss tensor(0.8401)
# val loss tensor(0.4827)
# val loss tensor(0.4452)
# val loss tensor(1.5729)
# val loss tensor(1.0735)
# val loss tensor(0.5445)
# val loss tensor(0.5923)
# val loss tensor(1.0315)
# val loss tensor(1.0748)
# val loss tensor(1.0832)
# val loss tensor(0.4876)
# val loss tensor(1.8359)
# val loss tensor(2.3583)
# val loss tensor(0.4130)
# val loss tensor(1.2308)
# val loss tensor(1.2217)
# val loss tensor(0.6034)
# val loss tensor(0.7239)
# val loss tensor(1.2395)
# val loss tensor(1.2329)
# val loss tensor(0.4248)
# val loss tensor(1.0124)
# val loss tensor(1.4659)
# val loss tensor(1.0005)
# val loss tensor(2.5447)
# val loss tensor(0.7377)
# val loss tensor(1.2115)
# val loss tensor(2.1518)
# val loss tensor(0.4233)
# val loss tensor(0.7738)
# val loss tensor(2.1733)
# val loss tensor(0.7714)
# val loss tensor(0.4439)
# val loss tensor(1.0972)
# val loss tensor(0.4490)
# val loss tensor(1.3277)
# val loss tensor(0.3677)
# val loss tensor(1.0977)
# val loss tensor(1.0349)
# val loss tensor(0.7800)
# val loss tensor(0.5203)
# val loss tensor(1.5328)
# val loss tensor(1.6574)
# val loss tensor(0.6066)
# val loss tensor(1.5217)
# val loss tensor(0.7972)
# val loss tensor(1.1515)
# val loss tensor(1.3358)
# val loss tensor(0.4165)
# val loss tensor(0.3486)
# val loss tensor(1.2431)
# val loss tensor(0.7479)
# val loss tensor(1.4985)
# val loss tensor(1.6944)
# val loss tensor(0.4881)
# val loss tensor(0.8779)
# val loss tensor(0.9316)
# val loss tensor(1.2303)
# val loss tensor(2.1601)
# val loss tensor(1.5145)
# val loss tensor(1.6123)
# val loss tensor(0.3603)
# val loss tensor(1.4054)
# val loss tensor(1.8515)
# val loss tensor(1.6214)
# val loss tensor(0.6569)
# val loss tensor(0.6635)
# val loss tensor(0.8127)
# val loss tensor(2.0011)
# val loss tensor(0.4717)
# val loss tensor(0.6269)
# val loss tensor(0.4296)
# val loss tensor(0.4741)
# val loss tensor(0.5306)
# val loss tensor(0.5090)
# val loss tensor(1.4633)
# val loss tensor(0.5622)
# val loss tensor(1.4856)
# val loss tensor(0.9214)
# val loss tensor(0.7038)
# val loss tensor(0.4964)
# val loss tensor(0.8532)
# val loss tensor(0.5995)
# val loss tensor(0.9457)
# val loss tensor(1.8174)
# val loss tensor(1.6427)
# val loss tensor(2.6057)
# val loss tensor(0.5748)
# val loss tensor(0.5312)
# Run 3 [Epoch 2] val loss: 1.3279e+01
# refY.shape (3756, 1, 16)
# 2 [np.float64(-0.03774324512263319), np.float64(0.14037711500864822), np.float64(-0.04925047583348212), np.float64(0.011622314155770027)] 2
# 0.001 0.0001 0.3 16 0.95
# bestCorr is defined
# 0 epoch: 1 ; loss 0.8932642936706543
# torch.float32
# 1 epoch: 1 ; loss 2.945805311203003
# torch.float32
# 2 epoch: 1 ; loss 1.843254804611206
# torch.float32
# Run 4 [Epoch 1] loss: 3.1869e+01
# val loss tensor(0.5743)
# val loss tensor(0.5846)
# val loss tensor(0.7772)
# val loss tensor(2.0182)
# val loss tensor(0.6801)
# val loss tensor(0.5136)
# val loss tensor(0.6233)
# val loss tensor(0.5723)
# val loss tensor(0.6428)
# val loss tensor(0.5598)
# val loss tensor(0.3202)
# val loss tensor(1.2898)
# val loss tensor(1.5961)
# val loss tensor(0.6640)
# val loss tensor(0.9162)
# val loss tensor(0.4373)
# val loss tensor(0.8004)
# val loss tensor(1.6507)
# val loss tensor(1.0996)
# val loss tensor(1.3282)
# val loss tensor(1.0118)
# val loss tensor(0.6742)
# val loss tensor(0.7808)
# val loss tensor(0.8072)
# val loss tensor(1.3630)
# val loss tensor(0.8932)
# val loss tensor(0.6880)
# val loss tensor(1.3127)
# val loss tensor(1.6637)
# val loss tensor(0.4997)
# val loss tensor(1.5490)
# val loss tensor(1.1188)
# val loss tensor(2.3535)
# val loss tensor(1.9237)
# val loss tensor(0.6502)
# val loss tensor(1.2134)
# val loss tensor(1.1711)
# val loss tensor(0.5563)
# val loss tensor(0.7989)
# val loss tensor(0.5995)
# val loss tensor(0.7445)
# val loss tensor(1.2182)
# val loss tensor(1.1622)
# val loss tensor(0.5454)
# val loss tensor(2.5549)
# val loss tensor(1.2997)
# val loss tensor(0.6817)
# val loss tensor(0.6426)
# val loss tensor(0.8662)
# val loss tensor(1.0460)
# val loss tensor(2.8086)
# val loss tensor(1.2300)
# val loss tensor(0.4183)
# val loss tensor(1.4016)
# val loss tensor(1.4032)
# val loss tensor(0.5093)
# val loss tensor(0.9158)
# val loss tensor(1.1368)
# val loss tensor(0.3799)
# val loss tensor(0.6452)
# val loss tensor(0.4939)
# val loss tensor(1.2466)
# val loss tensor(1.3190)
# val loss tensor(0.5524)
# val loss tensor(0.7501)
# val loss tensor(1.3263)
# val loss tensor(1.3301)
# val loss tensor(0.7538)
# val loss tensor(0.6901)
# val loss tensor(0.3214)
# val loss tensor(0.9537)
# val loss tensor(0.7584)
# val loss tensor(1.1080)
# val loss tensor(2.0693)
# val loss tensor(0.4662)
# val loss tensor(2.3421)
# val loss tensor(0.5505)
# val loss tensor(0.8253)
# val loss tensor(0.3077)
# val loss tensor(1.9853)
# val loss tensor(1.9336)
# val loss tensor(0.5014)
# val loss tensor(0.5857)
# val loss tensor(1.6018)
# val loss tensor(2.1013)
# val loss tensor(1.9218)
# val loss tensor(1.4938)
# val loss tensor(1.7335)
# val loss tensor(0.4467)
# val loss tensor(1.3586)
# val loss tensor(1.4888)
# val loss tensor(1.7733)
# val loss tensor(1.0092)
# val loss tensor(0.7396)
# val loss tensor(1.1536)
# val loss tensor(2.2640)
# val loss tensor(1.5754)
# val loss tensor(0.7148)
# val loss tensor(1.6422)
# val loss tensor(1.1598)
# val loss tensor(1.5823)
# val loss tensor(0.6173)
# val loss tensor(1.4139)
# val loss tensor(0.9967)
# val loss tensor(1.1885)
# val loss tensor(1.4708)
# val loss tensor(0.4687)
# val loss tensor(2.0537)
# val loss tensor(0.5073)
# val loss tensor(1.0062)
# val loss tensor(1.0648)
# val loss tensor(0.9969)
# val loss tensor(0.5407)
# val loss tensor(1.2789)
# val loss tensor(0.2212)
# val loss tensor(1.3059)
# val loss tensor(0.5159)
# val loss tensor(1.9230)
# val loss tensor(1.4645)
# val loss tensor(1.3024)
# val loss tensor(1.1806)
# val loss tensor(1.4127)
# val loss tensor(0.6256)
# val loss tensor(0.4302)
# val loss tensor(1.0352)
# val loss tensor(0.4093)
# val loss tensor(0.3053)
# val loss tensor(0.9738)
# val loss tensor(3.4576)
# val loss tensor(0.7359)
# val loss tensor(0.6601)
# val loss tensor(1.9684)
# val loss tensor(0.6966)
# val loss tensor(0.3311)
# val loss tensor(2.3674)
# val loss tensor(1.4837)
# val loss tensor(0.7813)
# val loss tensor(1.0444)
# val loss tensor(0.8667)
# val loss tensor(0.3621)
# val loss tensor(1.5975)
# val loss tensor(1.1584)
# val loss tensor(1.0580)
# val loss tensor(2.4625)
# val loss tensor(1.1803)
# val loss tensor(1.4072)
# val loss tensor(0.7228)
# val loss tensor(1.8086)
# val loss tensor(1.1796)
# val loss tensor(1.6368)
# val loss tensor(2.3227)
# val loss tensor(1.2095)
# val loss tensor(0.5077)
# val loss tensor(0.8624)
# val loss tensor(0.4798)
# val loss tensor(1.0775)
# val loss tensor(1.2786)
# val loss tensor(1.4951)
# val loss tensor(0.6534)
# val loss tensor(0.4818)
# val loss tensor(1.3570)
# val loss tensor(1.6104)
# val loss tensor(1.0250)
# val loss tensor(0.9743)
# val loss tensor(1.6358)
# val loss tensor(0.6027)
# val loss tensor(2.0084)
# val loss tensor(1.1729)
# ...
# val loss tensor(1.5454)
# val loss tensor(1.0549)
# val loss tensor(1.5333)
# val loss tensor(1.5192)
# val loss tensor(1.5011)
# val loss tensor(1.1002)
# val loss tensor(0.4627)
# val loss tensor(2.0166)
# val loss tensor(1.3251)
# val loss tensor(0.8920)
# val loss tensor(1.1737)
# val loss tensor(1.2394)
# val loss tensor(1.6376)
# val loss tensor(1.4272)
# val loss tensor(1.3912)
# val loss tensor(0.9977)
# val loss tensor(1.0120)
# val loss tensor(0.8897)
# val loss tensor(0.6734)
# val loss tensor(1.0627)
# val loss tensor(1.0532)
# val loss tensor(0.8215)
# val loss tensor(0.9870)
# val loss tensor(1.0574)
# val loss tensor(0.5071)
# val loss tensor(0.4426)
# val loss tensor(1.0189)
# val loss tensor(0.6508)
# val loss tensor(1.6135)
# val loss tensor(0.9752)
# val loss tensor(2.6381)
# val loss tensor(0.9408)
# val loss tensor(1.0881)
# val loss tensor(1.2411)
# val loss tensor(1.1006)
# val loss tensor(0.6093)
# val loss tensor(1.8859)
# val loss tensor(1.7207)
# val loss tensor(0.9184)
# val loss tensor(1.6944)
# val loss tensor(0.6647)
# val loss tensor(0.8314)
# val loss tensor(1.1006)
# val loss tensor(1.5528)
# val loss tensor(1.1837)
# val loss tensor(1.0770)
# val loss tensor(1.6980)
# val loss tensor(1.2723)
# val loss tensor(1.0279)
# val loss tensor(1.5774)
# val loss tensor(0.3648)
# val loss tensor(1.1551)
# val loss tensor(1.0433)
# val loss tensor(1.7570)
# val loss tensor(1.3566)
# val loss tensor(1.0792)
# val loss tensor(1.4281)
# val loss tensor(1.7030)
# val loss tensor(2.1168)
# val loss tensor(0.9210)
# val loss tensor(1.1349)
# val loss tensor(1.0354)
# val loss tensor(1.2870)
# val loss tensor(0.7703)
# val loss tensor(0.6758)
# val loss tensor(0.9727)
# val loss tensor(0.6136)
# val loss tensor(1.5514)
# val loss tensor(1.4712)
# val loss tensor(0.8989)
# val loss tensor(2.0493)
# val loss tensor(0.9190)
# val loss tensor(0.8621)
# val loss tensor(1.4674)
# val loss tensor(1.1635)
# val loss tensor(1.3652)
# val loss tensor(1.2103)
# val loss tensor(1.5556)
# val loss tensor(1.2719)
# val loss tensor(1.0559)
# val loss tensor(0.6283)
# val loss tensor(1.0624)
# val loss tensor(0.6598)
# val loss tensor(0.7643)
# val loss tensor(1.4381)
# val loss tensor(1.3488)
# val loss tensor(1.7343)
# val loss tensor(1.1432)
# val loss tensor(0.9774)
# val loss tensor(1.8508)
# val loss tensor(1.2778)
# val loss tensor(0.6965)
# val loss tensor(1.2287)
# val loss tensor(0.9960)
# val loss tensor(1.3152)
# val loss tensor(1.6735)
# val loss tensor(1.2049)
# val loss tensor(1.0476)
# val loss tensor(1.2114)
# val loss tensor(1.1361)
# val loss tensor(0.7778)
# val loss tensor(0.6914)
# val loss tensor(1.1842)
# val loss tensor(0.5342)
# val loss tensor(1.1794)
# val loss tensor(0.7371)
# val loss tensor(1.5135)
# val loss tensor(1.3275)
# val loss tensor(0.7651)
# val loss tensor(0.8677)
# val loss tensor(1.7330)
# val loss tensor(0.5505)
# val loss tensor(0.9012)
# val loss tensor(0.9525)
# val loss tensor(0.9580)
# val loss tensor(1.4985)
# val loss tensor(0.8697)
# val loss tensor(1.2079)
# val loss tensor(1.4494)
# val loss tensor(0.8031)
# val loss tensor(0.6172)
# val loss tensor(1.1211)
# val loss tensor(1.2019)
# val loss tensor(2.1351)
# val loss tensor(0.8876)
# val loss tensor(1.0799)
# val loss tensor(0.9168)
# val loss tensor(0.8880)
# val loss tensor(1.0769)
# val loss tensor(1.2624)
# val loss tensor(1.0824)
# val loss tensor(0.7846)
# val loss tensor(0.7537)
# val loss tensor(1.4985)
# val loss tensor(2.1659)
# val loss tensor(0.9850)
# val loss tensor(1.2185)
# val loss tensor(0.6460)
# val loss tensor(0.5199)
# val loss tensor(1.1998)
# val loss tensor(1.8203)
# val loss tensor(1.0703)
# val loss tensor(0.9324)
# val loss tensor(0.8380)
# val loss tensor(1.3155)
# val loss tensor(1.2787)
# val loss tensor(0.9752)
# val loss tensor(1.6934)
# Run 29 [Epoch 2] val loss: 1.4071e+01
# refY.shape (3756, 1, 16)
# 2 [np.float64(0.007739487627547544), np.float64(0.15125055906580182), np.float64(0.057296895154432245), np.float64(-0.07165548070219502)] 2
# 0.001 0.001 0.3 32 0.85
# bestCorr is defined
# 0 epoch: 1 ; loss 0.9624842405319214
# torch.float32
# 1 epoch: 1 ; loss 1.139732003211975
# torch.float32
# 2 epoch: 1 ; loss 0.9947418570518494
# torch.float32
# Run 30 [Epoch 1] loss: 2.1584e+01
# val loss tensor(2.3060)
# val loss tensor(0.4748)
# val loss tensor(0.5731)
# val loss tensor(0.8466)
# val loss tensor(1.1321)
# val loss tensor(0.9871)
# val loss tensor(1.2049)
# val loss tensor(0.8510)
# val loss tensor(0.6495)
# val loss tensor(0.9146)
# val loss tensor(1.5117)
# val loss tensor(0.8519)
# val loss tensor(0.7253)
# val loss tensor(0.7311)
# val loss tensor(1.5956)
# val loss tensor(0.8053)
# val loss tensor(1.1737)
# val loss tensor(1.9094)
# val loss tensor(1.0539)
# val loss tensor(0.6767)
# val loss tensor(1.3971)
# val loss tensor(0.5441)
# val loss tensor(0.9940)
# val loss tensor(1.1510)
# val loss tensor(0.5331)
# val loss tensor(0.9861)
# val loss tensor(1.0720)
# val loss tensor(1.3873)
# val loss tensor(1.2205)
# val loss tensor(2.1846)
# val loss tensor(1.4324)
# val loss tensor(0.7136)
# val loss tensor(1.4522)
# val loss tensor(1.1614)
# val loss tensor(1.8234)
# val loss tensor(0.7602)
# val loss tensor(1.2710)
# val loss tensor(0.6027)
# val loss tensor(1.6098)
# val loss tensor(0.8797)
# val loss tensor(1.2852)
# val loss tensor(1.5766)
# val loss tensor(0.5950)
# val loss tensor(0.9887)
# val loss tensor(1.2274)
# val loss tensor(1.5764)
# val loss tensor(0.9468)
# val loss tensor(1.1972)
# val loss tensor(0.8773)
# val loss tensor(1.0916)
# val loss tensor(1.4506)
# val loss tensor(0.8587)
# val loss tensor(0.9252)
# val loss tensor(2.4921)
# val loss tensor(1.1470)
# val loss tensor(0.8818)
# val loss tensor(1.4830)
# val loss tensor(1.0118)
# val loss tensor(0.5505)
# val loss tensor(1.9664)
# val loss tensor(1.4155)
# val loss tensor(1.3530)
# val loss tensor(1.9556)
# val loss tensor(1.0427)
# val loss tensor(1.1503)
# val loss tensor(0.6276)
# val loss tensor(0.6005)
# val loss tensor(0.7262)
# val loss tensor(1.6914)
# val loss tensor(1.1365)
# val loss tensor(0.4667)
# val loss tensor(0.6972)
# val loss tensor(0.6613)
# val loss tensor(1.2892)
# val loss tensor(1.1651)
# val loss tensor(1.2645)
# val loss tensor(1.7309)
# val loss tensor(1.1157)
# val loss tensor(1.5221)
# val loss tensor(1.1616)
# val loss tensor(0.5201)
# val loss tensor(0.8738)
# val loss tensor(0.9802)
# val loss tensor(0.9791)
# val loss tensor(2.3496)
# val loss tensor(1.0599)
# val loss tensor(3.4968)
# val loss tensor(0.8750)
# val loss tensor(0.5687)
# val loss tensor(0.5499)
# val loss tensor(0.8187)
# val loss tensor(1.5877)
# val loss tensor(0.6894)
# val loss tensor(1.1871)
# val loss tensor(0.8522)
# val loss tensor(1.2353)
# val loss tensor(1.1697)
# val loss tensor(0.9205)
# val loss tensor(1.1350)
# val loss tensor(1.7313)
# val loss tensor(0.6696)
# val loss tensor(0.9006)
# val loss tensor(0.7683)
# val loss tensor(0.5648)
# val loss tensor(0.9661)
# val loss tensor(0.5208)
# val loss tensor(1.1197)
# val loss tensor(1.8802)
# val loss tensor(0.8889)
# val loss tensor(2.4916)
# val loss tensor(1.0510)
# val loss tensor(2.2088)
# val loss tensor(0.9081)
# val loss tensor(1.0038)
# val loss tensor(0.8395)
# val loss tensor(0.9665)
# val loss tensor(0.7085)
# val loss tensor(0.7383)
# val loss tensor(1.2914)
# val loss tensor(0.7011)
# val loss tensor(0.9615)
# val loss tensor(0.7483)
# val loss tensor(0.8568)
# val loss tensor(0.6712)
# val loss tensor(0.6015)
# val loss tensor(0.8787)
# val loss tensor(1.2753)
# val loss tensor(0.8632)
# val loss tensor(1.6675)
# val loss tensor(1.6967)
# val loss tensor(1.9572)
# val loss tensor(0.3859)
# val loss tensor(1.4237)
# val loss tensor(0.7350)
# val loss tensor(1.1989)
# val loss tensor(0.7324)
# val loss tensor(1.6377)
# val loss tensor(0.9101)
# val loss tensor(1.4780)
# val loss tensor(0.7658)
# val loss tensor(2.7049)
# val loss tensor(1.4841)
# val loss tensor(0.4542)
# val loss tensor(0.7709)
# val loss tensor(1.2012)
# val loss tensor(0.6379)
# val loss tensor(0.6436)
# val loss tensor(1.1980)
# val loss tensor(1.3923)
# val loss tensor(1.5009)
# val loss tensor(1.8313)
# val loss tensor(1.1844)
# val loss tensor(1.8546)
# val loss tensor(1.9545)
# val loss tensor(0.8181)
# val loss tensor(0.8762)
# val loss tensor(0.9283)
# val loss tensor(1.1998)
# val loss tensor(0.4048)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 31
#      29 for batch_size in batch_sizes:
#      30     for gamma in gammas:
# ---> 31         start_training(train_set, val_set, test_set, train_steps, epochs)
#      32         print(lr, weight_decay, dropout, batch_size, gamma)
#      33         run_count += 1
#
# Cell In[5], line 121, in start_training(train_set, val_set, test_set, train_steps, epochs)
#     119 for epoch in range(1, epochs + 1):
#     120     tlosses = train(train_load, epoch, run_count, train_steps)
# --> 121     vlosses = validate(len(val_set)//batch_size, epoch, run_count)
#     122     scheduler.step()
#     124     train_Loss[epoch-1] = tlosses[0]
#
# Cell In[5], line 74, in start_training.<locals>.validate(val_steps, epoch, run_count)
#      72 running_loss = 0.0
#      73 running_loss_y = 0.0
# ---> 74 for i, data in enumerate(val_load):
#      75     loss, y_loss = doStep(data)
#      76     print("val loss", loss)
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:788, in _SingleProcessDataLoaderIter._next_data(self)
#     786 def _next_data(self):
#     787     index = self._next_index()  # may raise StopIteration
# --> 788     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789     if self._pin_memory:
#     790         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/Documents/ML/solar_weather/solar_wind/notebooks/../codes/make_dataset.py:56, in DatasetHist.__getitem__(self, idx)
#      54 def __getitem__(self, idx:int):
#      55     ID = self.ids[idx]
# ---> 56     X = self.data[self.X_clmns].loc[self.data.idx==ID].values.reshape(32, -1).transpose() #------------------------# 13x32 np.array
#      57     y = self.data[self.y_clmns].loc[self.data.idx==ID].values.reshape(16, -1).transpose() #------------------------# 16  np.array, as time is not choosen in the target
#      59     return ID, X, y
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4128, in DataFrame.__getitem__(self, key)
#    4125 if isinstance(indexer, slice):
#    4126     return self._slice(indexer, axis=1)
# -> 4128 data = self._take_with_is_copy(indexer, axis=1)
#    4130 if is_single_key:
#    4131     # What does looking for a single key in a non-unique index return?
#    4132     # The behavior is inconsistent. It returns a Series, except when
#    4133     # - the key itself is repeated (test on data.shape, #9519), or
#    4134     # - we have a MultiIndex on columns (test on self.columns, #21309)
#    4135     if data.shape[1] == 1 and not isinstance(self.columns, MultiIndex):
#    4136         # GH#26490 using data[key] can cause RecursionError
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/pandas/core/generic.py:4175, in NDFrame._take_with_is_copy(self, indices, axis)
#    4164 @final
#    4165 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4166     """
#    4167     Internal version of the `take` method that sets the `_is_copy`
#    4168     attribute to keep track of the parent dataframe (using in indexing
#    (...)   4173     See the docstring of `take` for full explanation of the parameters.
#    4174     """
# -> 4175     result = self.take(indices=indices, axis=axis)
#    4176     # Maybe set copy if we didn't actually change the index.
#    4177     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/pandas/core/generic.py:4155, in NDFrame.take(self, indices, axis, **kwargs)
#    4150     # We can get here with a slice via DataFrame.__getitem__
#    4151     indices = np.arange(
#    4152         indices.start, indices.stop, indices.step, dtype=np.intp
#    4153     )
# -> 4155 new_data = self._mgr.take(
#    4156     indices,
#    4157     axis=self._get_block_manager_axis(axis),
#    4158     verify=True,
#    4159 )
#    4160 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4161     self, method="take"
#    4162 )
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:913, in BaseBlockManager.take(self, indexer, axis, verify)
#     910 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     912 new_labels = self.axes[axis].take(indexer)
# --> 913 return self.reindex_indexer(
#     914     new_axis=new_labels,
#     915     indexer=indexer,
#     916     axis=axis,
#     917     allow_dups=True,
#     918     copy=None,
#     919 )
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:699, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     696     raise IndexError("Requested axis not found in manager")
#     698 if axis == 0:
# --> 699     new_blocks = self._slice_take_blocks_ax0(
#     700         indexer,
#     701         fill_value=fill_value,
#     702         only_slice=only_slice,
#     703         use_na_proxy=use_na_proxy,
#     704     )
#     705 else:
#     706     new_blocks = [
#     707         blk.take_nd(
#     708             indexer,
#    (...)    714         for blk in self.blocks
#     715     ]
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:862, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy, ref_inplace_op)
#     860                     blocks.append(nb)
#     861             else:
# --> 862                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     863                 blocks.append(nb)
#     865 return blocks
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1373, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1370     allow_fill = True
#    1372 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1373 new_values = algos.take_nd(
#    1374     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1375 )
#    1377 # Called from three places in managers, all of which satisfy
#    1378 #  these assertions
#    1379 if isinstance(self, ExtensionBlock):
#    1380     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1381     #  algos.take_nd call above.
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~/Documents/ML/solar_weather/.venv/lib/python3.12/site-packages/pandas/core/array_algos/take.py:162, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
# --> 162 func(arr, indexer, out, fill_value)
#     164 if flip_order:
#     165     out = out.T
#
# KeyboardInterrupt:

# %%
def start_training(train_set, val_set, test_set, train_steps, epochs):
    # Get data loaded
    train_load = DataLoader(train_set, batch_size=batch_size, shuffle=True)
    val_load = DataLoader(val_set, batch_size=batch_size, shuffle=True)
    test_load = DataLoader(test_set, batch_size=len(test_set), shuffle=False)

    # Load model
    model = mnn.model_base(xCh=13, LEN=32, emDim=128, dropout=dropout, device=None)
    # Use GPU
    # model = model.to(device)

    # Inititialize optimizer ans scheduler
    optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = StepLR(optimizer, step_size=1, gamma=gamma)

    train_Loss_y = np.empty(epochs,dtype=np.float32)
    train_Loss_diff = np.empty(epochs,dtype=np.float32)
    train_Loss = np.empty(epochs,dtype=np.float32)
    val_Loss_y = np.empty(epochs,dtype=np.float32)
    val_Loss_diff = np.empty(epochs,dtype=np.float32)
    val_Loss  = np.empty(epochs,dtype=np.float32)

    bestCorr = [-1.0,-1.0,-1.0,-1.0]
    print('bestCorr is defined')
    bestMse = [999.0,999.0,999.0,999.0]
    bestEpoch = epochs
    paraString = 'lr%0.2e_wd%0.2e_drp%0.2f_bS%d_E%d_sR%0.2f'%(lr, weight_decay, dropout, batch_size, epochs, gamma)

    def train(data_load, epoch, run_count=run_count, train_steps=train_steps):
        model.train()
        running_loss = 0.0
        running_loss_y = 0.0
        for i, data in enumerate(data_load):
            # zero the parameter gradients
            optimizer.zero_grad()
            loss, y_loss = doStep(data)
            print(i, "epoch:", epoch, ";", "loss", loss.item())
            del data

            print(loss.dtype)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            running_loss_y += y_loss.item()
            if i == train_steps:
                break

        # print statistics
        running_loss = running_loss/train_steps
        running_loss_y = running_loss_y/train_steps
        print('Run %d [Epoch %d] loss: %.4e' %(run_count, epoch, running_loss_y*800.0))
        return running_loss, running_loss_y

    def doStep(data):
        x = data[1].to(torch.float32)
        # print("x", x)
        y = data[2].to(torch.float32)
        y_out = model(x)
        # print("Before backward:", torch.isnan(y_out).any()) 

        loss = F.mse_loss(y_out, y, reduction='none')
        loss = loss * y * 100.0 # Why this scaling
        loss = loss.mean()
        y_loss = F.mse_loss(y_out,y)

        return loss, y_loss

    def validate(val_steps, epoch, run_count):
        model.eval()
        with torch.no_grad():
            running_loss = 0.0
            running_loss_y = 0.0
            for i, data in enumerate(val_load):
                loss, y_loss = doStep(data)
                print("val loss", loss)
                del data
    
                running_loss += loss.item()
                running_loss_y += y_loss.item()
                if i == val_steps:
                    break
    
            # print statistics
            running_loss = running_loss/val_steps
            running_loss_y = running_loss_y/val_steps
            print('Run %d [Epoch %d] val loss: %.4e' %(run_count, epoch, running_loss_y*800.0))
        return running_loss, running_loss_y

    def evalModel(bestCorr, bestMse, bestEpoch):
        model.eval()
        with torch.no_grad():
            for batch in test_load:
                testBatch = batch
                break
            x = testBatch[1].to(torch.float32)
            # y = testBatch[2]
            opY = model(x).detach().cpu().numpy()

        refY = testBatch[2].numpy()
        print("refY.shape", refY.shape)

        corrVals = [-1.0,-1.0,-1.0,-1.0]
        mseVals = [300.0,300.0,300.0,300.0]
        refIds = [9,11,13,15]
        for i in range(4):
            thisRef = refY[:, :, refIds[i]].flatten()
            thisOp = opY[:, :, refIds[i]].flatten()
            corrVals[i] = pearsonr(thisRef,thisOp)[0]
            mseVals[i] = np.mean(np.sqrt((thisOp-thisRef)**2)*800.0)
        if corrVals[-1] > bestCorr[-1]:
            bestCorr = corrVals
            torch.save(model.state_dict(), resultsPath + 'models/%s_%s'%(mString,paraString))
            bestMse = mseVals
            bestEpoch = epoch
        print(epoch, bestCorr, bestEpoch)
        return bestCorr, bestMse, bestEpoch  

    for epoch in range(1, epochs + 1):
        tlosses = train(train_load, epoch, run_count, train_steps)
        vlosses = validate(len(val_set)//batch_size, epoch, run_count)
        scheduler.step()

        train_Loss[epoch-1] = tlosses[0]
        val_Loss[epoch-1] = vlosses[0]
        
        train_Loss_y[epoch-1] = tlosses[1]
        val_Loss_y[epoch-1] = vlosses[1]
        
        if epoch > 1:
    	    bestCorr, bestMse, bestEpoch = evalModel(bestCorr, bestMse, bestEpoch)
    
    train_Loss.dump(resultsPath + 'losses/%s_train_%s'%(mString,paraString))
    val_Loss.dump(resultsPath + 'losses/%s_val_%s'%(mString,paraString))
    train_Loss_y.dump(resultsPath + 'losses/%s_train_y_%s'%(mString,paraString))
    val_Loss_y.dump(resultsPath + 'losses/%s_val_y_%s'%(mString,paraString))
    with open(resultsPath + 'corrsM2e','a') as fl:
        #fl.write('%s_%s\t%0.6f\t%0.6f\t%d\n'%(mString,paraString,bestCorr,bestMse,bestEpoch))
        fl.write('%s_%s'%(mString,paraString))
        for i in range(4):
            fl.write('\t%0.6f\t%0.6f'%(bestCorr[i],bestMse[i]))
        fl.write('\t%d\n'%bestEpoch)
    print(lr, time.time() - startT)
    return

# %%
train_df = pd.read_csv(train_path)

# %%
(train_df.loc[:, train_df.columns != "idx"].min() < 0).sum()
# Out:
# np.int64(0)
