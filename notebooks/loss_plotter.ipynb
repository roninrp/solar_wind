# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
loss_path = "../model_outputs/losses/"

# %%
loss_list = os.listdir(loss_path)

# %%
loss_list[0], loss_list[30]
# Out:
# ('base_test_en_train_y_lr1.00e-03_wd1.00e-04_drp0.20_bS32_E5_sR0.95',
#  'base_test_en_train_lr1.00e-03_wd1.00e-03_drp0.40_bS64_E5_sR0.95')

# %%
with open(loss_path + loss_list[30], "rb") as fl:
    data = pickle.load(fl)

# %%
plt.plot(data)
